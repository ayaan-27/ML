# %% [markdown]
# <a href="https://colab.research.google.com/github/ayaan-27/ML/blob/master/Exp_7_J023_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns
from keras import models
from keras import layers
from keras import optimizers
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import LabelEncoder, StandardScaler
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !wget -O Titanic.csv "https://raw.githubusercontent.com/pranavn91/blockchain/master/train.csv"
# Out:
# --2020-09-18 07:02:22--  https://raw.githubusercontent.com/pranavn91/blockchain/master/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61194 (60K) [text/plain]
# Saving to: ‘Titanic.csv’
#
# Titanic.csv         100%[===================>]  59.76K  --.-KB/s    in 0.03s
#
# 2020-09-18 07:02:22 (2.29 MB/s) - ‘Titanic.csv’ saved [61194/61194]

# %%
titanic=pd.read_csv("Titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Age'].fillna(titanic['Age'].median(), inplace = True)

titanic.drop(['Cabin','PassengerId', 'Name','Ticket'], axis = 1, inplace = True)

# %%
titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic['Embarked'].fillna('S',inplace=True)

# %%
titanic.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df_num = titanic.select_dtypes(include=[np.number]).copy()
df_num
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3  28.0      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
df_cat = titanic.select_dtypes(include='object').copy()
df_cat
# Out:
#         Sex Embarked
# 0      male        S
# 1    female        C
# 2    female        S
# 3    female        S
# 4      male        S
# ..      ...      ...
# 886    male        S
# 887  female        S
# 888  female        S
# 889    male        C
# 890    male        Q
#
# [891 rows x 2 columns]

# %%
df_cat = pd.get_dummies(df_cat)
df_cat
# Out:
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0             0         1           0           0           1
# 1             1         0           1           0           0
# 2             1         0           0           0           1
# 3             1         0           0           0           1
# 4             0         1           0           0           1
# ..          ...       ...         ...         ...         ...
# 886           0         1           0           0           1
# 887           1         0           0           0           1
# 888           1         0           0           0           1
# 889           0         1           1           0           0
# 890           0         1           0           1           0
#
# [891 rows x 5 columns]

# %%
titanic = pd.concat([df_num,df_cat],axis=1)
titanic
# Out:
#      Survived  Pclass   Age  ...  Embarked_C  Embarked_Q  Embarked_S
# 0           0       3  22.0  ...           0           0           1
# 1           1       1  38.0  ...           1           0           0
# 2           1       3  26.0  ...           0           0           1
# 3           1       1  35.0  ...           0           0           1
# 4           0       3  35.0  ...           0           0           1
# ..        ...     ...   ...  ...         ...         ...         ...
# 886         0       2  27.0  ...           0           0           1
# 887         1       1  19.0  ...           0           0           1
# 888         0       3  28.0  ...           0           0           1
# 889         1       1  26.0  ...           1           0           0
# 890         0       3  32.0  ...           0           1           0
#
# [891 rows x 11 columns]

# %%
titanic.drop(columns=['Sex_male','Embarked_C'],inplace=True)
titanic
# Out:
#      Survived  Pclass   Age  SibSp  ...     Fare  Sex_female  Embarked_Q  Embarked_S
# 0           0       3  22.0      1  ...   7.2500           0           0           1
# 1           1       1  38.0      1  ...  71.2833           1           0           0
# 2           1       3  26.0      0  ...   7.9250           1           0           1
# 3           1       1  35.0      1  ...  53.1000           1           0           1
# 4           0       3  35.0      0  ...   8.0500           0           0           1
# ..        ...     ...   ...    ...  ...      ...         ...         ...         ...
# 886         0       2  27.0      0  ...  13.0000           0           0           1
# 887         1       1  19.0      0  ...  30.0000           1           0           1
# 888         0       3  28.0      1  ...  23.4500           1           0           1
# 889         1       1  26.0      0  ...  30.0000           0           0           0
# 890         0       3  32.0      0  ...   7.7500           0           1           0
#
# [891 rows x 9 columns]

# %%
cormat = titanic.corr()
fig, ax = plt.subplots(figsize = [8,4])
sns.heatmap(data = cormat, annot=True)
plt.show()

# %% [markdown]
# ## NN MODEL

# %%
X = titanic.drop(columns=['Survived'])
Y = titanic['Survived']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.05)
print("x_train_shape"+str(x_train.shape))
print("y_train_shape"+str(y_train.shape))
print("x_test_shape"+str(x_test.shape))
print("y_test_shape"+str(y_test.shape))
# Out:
# x_train_shape(846, 8)
# y_train_shape(846,)
# x_test_shape(45, 8)
# y_test_shape(45,)

# %%
nn = models.Sequential()
nn.add(layers.Dense(512, activation="tanh",input_shape=(8, )))
nn.add(layers.Dense(256, activation="sigmoid"))
nn.add(layers.Dense(64, activation="tanh"))
nn.add(layers.Dense(32, activation="relu"))
nn.add(layers.Dense(16, activation="tanh"))
nn.add(layers.Dense(1, activation="sigmoid"))

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               4608
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 155,009
# Trainable params: 155,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(optimizer="rmsprop",
           loss='binary_crossentropy',
           metrics = ['accuracy'])

# %%
#hyperpara
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=300)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = nn.fit(x_train,y_train, epochs=5000, validation_split=0.05, verbose=0, callbacks=[es, mc])
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.69767, saving model to best_model.h5
#
# Epoch 00002: val_accuracy did not improve from 0.69767
#
# Epoch 00003: val_accuracy did not improve from 0.69767
#
# Epoch 00004: val_accuracy improved from 0.69767 to 0.72093, saving model to best_model.h5
#
# Epoch 00005: val_accuracy did not improve from 0.72093
#
# Epoch 00006: val_accuracy did not improve from 0.72093
#
# Epoch 00007: val_accuracy did not improve from 0.72093
#
# Epoch 00008: val_accuracy improved from 0.72093 to 0.74419, saving model to best_model.h5
#
# Epoch 00009: val_accuracy did not improve from 0.74419
#
# Epoch 00010: val_accuracy did not improve from 0.74419
#
# Epoch 00011: val_accuracy did not improve from 0.74419
#
# Epoch 00012: val_accuracy improved from 0.74419 to 0.79070, saving model to best_model.h5
#
# Epoch 00013: val_accuracy did not improve from 0.79070
#
# Epoch 00014: val_accuracy improved from 0.79070 to 0.86047, saving model to best_model.h5
#
# Epoch 00015: val_accuracy did not improve from 0.86047
#
# Epoch 00016: val_accuracy did not improve from 0.86047
#
# Epoch 00017: val_accuracy did not improve from 0.86047
#
# Epoch 00018: val_accuracy did not improve from 0.86047
#
# Epoch 00019: val_accuracy did not improve from 0.86047
#
# Epoch 00020: val_accuracy did not improve from 0.86047
#
# Epoch 00021: val_accuracy did not improve from 0.86047
#
# Epoch 00022: val_accuracy did not improve from 0.86047
#
# Epoch 00023: val_accuracy did not improve from 0.86047
#
# Epoch 00024: val_accuracy did not improve from 0.86047
#
# Epoch 00025: val_accuracy did not improve from 0.86047
#
# Epoch 00026: val_accuracy did not improve from 0.86047
#
# Epoch 00027: val_accuracy did not improve from 0.86047
#
# Epoch 00028: val_accuracy did not improve from 0.86047
#
# Epoch 00029: val_accuracy improved from 0.86047 to 0.88372, saving model to best_model.h5
#
# Epoch 00030: val_accuracy did not improve from 0.88372
#
# Epoch 00031: val_accuracy did not improve from 0.88372
#
# Epoch 00032: val_accuracy did not improve from 0.88372
#
# Epoch 00033: val_accuracy did not improve from 0.88372
#
# Epoch 00034: val_accuracy did not improve from 0.88372
#
# Epoch 00035: val_accuracy did not improve from 0.88372
#
# Epoch 00036: val_accuracy did not improve from 0.88372
#
# Epoch 00037: val_accuracy did not improve from 0.88372
#
# Epoch 00038: val_accuracy did not improve from 0.88372
#
# Epoch 00039: val_accuracy did not improve from 0.88372
#
# Epoch 00040: val_accuracy did not improve from 0.88372
#
# Epoch 00041: val_accuracy did not improve from 0.88372
#
# Epoch 00042: val_accuracy did not improve from 0.88372
#
# Epoch 00043: val_accuracy did not improve from 0.88372
#
# Epoch 00044: val_accuracy did not improve from 0.88372
#
# Epoch 00045: val_accuracy did not improve from 0.88372
#
# Epoch 00046: val_accuracy did not improve from 0.88372
#
# Epoch 00047: val_accuracy did not improve from 0.88372
#
# Epoch 00048: val_accuracy did not improve from 0.88372
#
# Epoch 00049: val_accuracy did not improve from 0.88372
#
# Epoch 00050: val_accuracy did not improve from 0.88372
#
# Epoch 00051: val_accuracy did not improve from 0.88372
#
# Epoch 00052: val_accuracy did not improve from 0.88372
#
# Epoch 00053: val_accuracy did not improve from 0.88372
#
# Epoch 00054: val_accuracy did not improve from 0.88372
#
# Epoch 00055: val_accuracy did not improve from 0.88372
#
# Epoch 00056: val_accuracy did not improve from 0.88372
#
# Epoch 00057: val_accuracy did not improve from 0.88372
#
# Epoch 00058: val_accuracy did not improve from 0.88372
#
# Epoch 00059: val_accuracy did not improve from 0.88372
#
# Epoch 00060: val_accuracy did not improve from 0.88372
#
# Epoch 00061: val_accuracy did not improve from 0.88372
#
# Epoch 00062: val_accuracy did not improve from 0.88372
#
# Epoch 00063: val_accuracy did not improve from 0.88372
#
# Epoch 00064: val_accuracy did not improve from 0.88372
#
# Epoch 00065: val_accuracy did not improve from 0.88372
#
# Epoch 00066: val_accuracy did not improve from 0.88372
#
# Epoch 00067: val_accuracy did not improve from 0.88372
#
# Epoch 00068: val_accuracy did not improve from 0.88372
#
# Epoch 00069: val_accuracy did not improve from 0.88372
#
# Epoch 00070: val_accuracy did not improve from 0.88372
#
# Epoch 00071: val_accuracy did not improve from 0.88372
#
# Epoch 00072: val_accuracy did not improve from 0.88372
#
# Epoch 00073: val_accuracy did not improve from 0.88372
#
# Epoch 00074: val_accuracy did not improve from 0.88372
#
# Epoch 00075: val_accuracy did not improve from 0.88372
#
# Epoch 00076: val_accuracy did not improve from 0.88372
#
# Epoch 00077: val_accuracy did not improve from 0.88372
#
# Epoch 00078: val_accuracy did not improve from 0.88372
#
# Epoch 00079: val_accuracy did not improve from 0.88372
#
# Epoch 00080: val_accuracy did not improve from 0.88372
#
# Epoch 00081: val_accuracy did not improve from 0.88372
#
# Epoch 00082: val_accuracy did not improve from 0.88372
#
# Epoch 00083: val_accuracy did not improve from 0.88372
#
# Epoch 00084: val_accuracy did not improve from 0.88372
#
# Epoch 00085: val_accuracy did not improve from 0.88372
#
# Epoch 00086: val_accuracy did not improve from 0.88372
#
# Epoch 00087: val_accuracy did not improve from 0.88372
#
# Epoch 00088: val_accuracy did not improve from 0.88372
#
# Epoch 00089: val_accuracy did not improve from 0.88372
#
# Epoch 00090: val_accuracy did not improve from 0.88372
#
# Epoch 00091: val_accuracy did not improve from 0.88372
#
# Epoch 00092: val_accuracy did not improve from 0.88372
#
# Epoch 00093: val_accuracy did not improve from 0.88372
#
# Epoch 00094: val_accuracy did not improve from 0.88372
#
# Epoch 00095: val_accuracy did not improve from 0.88372
#
# Epoch 00096: val_accuracy did not improve from 0.88372
#
# Epoch 00097: val_accuracy did not improve from 0.88372
#
# Epoch 00098: val_accuracy did not improve from 0.88372
#
# Epoch 00099: val_accuracy did not improve from 0.88372
#
# Epoch 00100: val_accuracy did not improve from 0.88372
#
# Epoch 00101: val_accuracy did not improve from 0.88372
#
# Epoch 00102: val_accuracy did not improve from 0.88372
#
# Epoch 00103: val_accuracy did not improve from 0.88372
#
# Epoch 00104: val_accuracy did not improve from 0.88372
#
# Epoch 00105: val_accuracy did not improve from 0.88372
#
# Epoch 00106: val_accuracy did not improve from 0.88372
#
# Epoch 00107: val_accuracy did not improve from 0.88372
#
# Epoch 00108: val_accuracy did not improve from 0.88372
#
# Epoch 00109: val_accuracy did not improve from 0.88372
#
# Epoch 00110: val_accuracy did not improve from 0.88372
#
# Epoch 00111: val_accuracy did not improve from 0.88372
#
# Epoch 00112: val_accuracy did not improve from 0.88372
#
# Epoch 00113: val_accuracy did not improve from 0.88372
#
# Epoch 00114: val_accuracy did not improve from 0.88372
#
# Epoch 00115: val_accuracy did not improve from 0.88372
#
# Epoch 00116: val_accuracy did not improve from 0.88372
#
# Epoch 00117: val_accuracy did not improve from 0.88372
#
# Epoch 00118: val_accuracy did not improve from 0.88372
#
# Epoch 00119: val_accuracy did not improve from 0.88372
#
# Epoch 00120: val_accuracy did not improve from 0.88372
#
# Epoch 00121: val_accuracy did not improve from 0.88372
#
# Epoch 00122: val_accuracy did not improve from 0.88372
#
# Epoch 00123: val_accuracy did not improve from 0.88372
#
# Epoch 00124: val_accuracy did not improve from 0.88372
#
# Epoch 00125: val_accuracy did not improve from 0.88372
#
# Epoch 00126: val_accuracy did not improve from 0.88372
#
# Epoch 00127: val_accuracy did not improve from 0.88372
#
# Epoch 00128: val_accuracy did not improve from 0.88372
#
# Epoch 00129: val_accuracy did not improve from 0.88372
#
# Epoch 00130: val_accuracy did not improve from 0.88372
#
# Epoch 00131: val_accuracy did not improve from 0.88372
#
# Epoch 00132: val_accuracy did not improve from 0.88372
#
# Epoch 00133: val_accuracy did not improve from 0.88372
#
# Epoch 00134: val_accuracy did not improve from 0.88372
#
# Epoch 00135: val_accuracy did not improve from 0.88372
#
# Epoch 00136: val_accuracy did not improve from 0.88372
#
# Epoch 00137: val_accuracy did not improve from 0.88372
#
# Epoch 00138: val_accuracy did not improve from 0.88372
#
# Epoch 00139: val_accuracy did not improve from 0.88372
#
# Epoch 00140: val_accuracy did not improve from 0.88372
#
# Epoch 00141: val_accuracy did not improve from 0.88372
#
# Epoch 00142: val_accuracy did not improve from 0.88372
#
# Epoch 00143: val_accuracy did not improve from 0.88372
#
# Epoch 00144: val_accuracy did not improve from 0.88372
#
# Epoch 00145: val_accuracy did not improve from 0.88372
#
# Epoch 00146: val_accuracy did not improve from 0.88372
#
# Epoch 00147: val_accuracy did not improve from 0.88372
#
# Epoch 00148: val_accuracy did not improve from 0.88372
#
# Epoch 00149: val_accuracy did not improve from 0.88372
#
# Epoch 00150: val_accuracy did not improve from 0.88372
#
# Epoch 00151: val_accuracy did not improve from 0.88372
#
# Epoch 00152: val_accuracy did not improve from 0.88372
#
# Epoch 00153: val_accuracy did not improve from 0.88372
#
# Epoch 00154: val_accuracy did not improve from 0.88372
#
# Epoch 00155: val_accuracy did not improve from 0.88372
#
# Epoch 00156: val_accuracy did not improve from 0.88372
#
# Epoch 00157: val_accuracy did not improve from 0.88372
#
# Epoch 00158: val_accuracy did not improve from 0.88372
#
# Epoch 00159: val_accuracy did not improve from 0.88372
#
# Epoch 00160: val_accuracy did not improve from 0.88372
#
# Epoch 00161: val_accuracy did not improve from 0.88372
#
# Epoch 00162: val_accuracy did not improve from 0.88372
#
# Epoch 00163: val_accuracy did not improve from 0.88372
#
# Epoch 00164: val_accuracy did not improve from 0.88372
#
# Epoch 00165: val_accuracy did not improve from 0.88372
#
# Epoch 00166: val_accuracy did not improve from 0.88372
#
# Epoch 00167: val_accuracy did not improve from 0.88372
#
# Epoch 00168: val_accuracy did not improve from 0.88372
#
# Epoch 00169: val_accuracy did not improve from 0.88372
#
# Epoch 00170: val_accuracy did not improve from 0.88372
#
# Epoch 00171: val_accuracy did not improve from 0.88372
#
# Epoch 00172: val_accuracy did not improve from 0.88372
#
# Epoch 00173: val_accuracy did not improve from 0.88372
#
# Epoch 00174: val_accuracy did not improve from 0.88372
#
# Epoch 00175: val_accuracy did not improve from 0.88372
#
# Epoch 00176: val_accuracy did not improve from 0.88372
#
# Epoch 00177: val_accuracy did not improve from 0.88372
#
# Epoch 00178: val_accuracy did not improve from 0.88372
#
# Epoch 00179: val_accuracy did not improve from 0.88372
#
# Epoch 00180: val_accuracy did not improve from 0.88372
#
# Epoch 00181: val_accuracy did not improve from 0.88372
#
# Epoch 00182: val_accuracy did not improve from 0.88372
#
# Epoch 00183: val_accuracy did not improve from 0.88372
#
# Epoch 00184: val_accuracy did not improve from 0.88372
#
# Epoch 00185: val_accuracy did not improve from 0.88372
#
# Epoch 00186: val_accuracy did not improve from 0.88372
#
# Epoch 00187: val_accuracy did not improve from 0.88372
#
# Epoch 00188: val_accuracy did not improve from 0.88372
#
# Epoch 00189: val_accuracy did not improve from 0.88372
#
# Epoch 00190: val_accuracy did not improve from 0.88372
#
# Epoch 00191: val_accuracy did not improve from 0.88372
#
# Epoch 00192: val_accuracy did not improve from 0.88372
#
# Epoch 00193: val_accuracy did not improve from 0.88372
#
# Epoch 00194: val_accuracy did not improve from 0.88372
#
# Epoch 00195: val_accuracy did not improve from 0.88372
#
# Epoch 00196: val_accuracy did not improve from 0.88372
#
# Epoch 00197: val_accuracy did not improve from 0.88372
#
# Epoch 00198: val_accuracy did not improve from 0.88372
#
# Epoch 00199: val_accuracy did not improve from 0.88372
#
# Epoch 00200: val_accuracy did not improve from 0.88372
#
# Epoch 00201: val_accuracy did not improve from 0.88372
#
# Epoch 00202: val_accuracy did not improve from 0.88372
#
# Epoch 00203: val_accuracy did not improve from 0.88372
#
# Epoch 00204: val_accuracy did not improve from 0.88372
#
# Epoch 00205: val_accuracy did not improve from 0.88372
#
# Epoch 00206: val_accuracy did not improve from 0.88372
#
# Epoch 00207: val_accuracy did not improve from 0.88372
#
# Epoch 00208: val_accuracy did not improve from 0.88372
#
# Epoch 00209: val_accuracy did not improve from 0.88372
#
# Epoch 00210: val_accuracy did not improve from 0.88372
#
# Epoch 00211: val_accuracy did not improve from 0.88372
#
# Epoch 00212: val_accuracy did not improve from 0.88372
#
# Epoch 00213: val_accuracy did not improve from 0.88372
#
# Epoch 00214: val_accuracy did not improve from 0.88372
#
# Epoch 00215: val_accuracy did not improve from 0.88372
#
# Epoch 00216: val_accuracy did not improve from 0.88372
#
# Epoch 00217: val_accuracy did not improve from 0.88372
#
# Epoch 00218: val_accuracy did not improve from 0.88372
#
# Epoch 00219: val_accuracy did not improve from 0.88372
#
# Epoch 00220: val_accuracy did not improve from 0.88372
#
# Epoch 00221: val_accuracy did not improve from 0.88372
#
# Epoch 00222: val_accuracy did not improve from 0.88372
#
# Epoch 00223: val_accuracy did not improve from 0.88372
#
# Epoch 00224: val_accuracy did not improve from 0.88372
#
# Epoch 00225: val_accuracy did not improve from 0.88372
#
# Epoch 00226: val_accuracy did not improve from 0.88372
#
# Epoch 00227: val_accuracy did not improve from 0.88372
#
# Epoch 00228: val_accuracy did not improve from 0.88372
#
# Epoch 00229: val_accuracy did not improve from 0.88372
#
# Epoch 00230: val_accuracy did not improve from 0.88372
#
# Epoch 00231: val_accuracy did not improve from 0.88372
#
# Epoch 00232: val_accuracy did not improve from 0.88372
#
# Epoch 00233: val_accuracy did not improve from 0.88372
#
# Epoch 00234: val_accuracy did not improve from 0.88372
#
# Epoch 00235: val_accuracy did not improve from 0.88372
#
# Epoch 00236: val_accuracy did not improve from 0.88372
#
# Epoch 00237: val_accuracy did not improve from 0.88372
#
# Epoch 00238: val_accuracy did not improve from 0.88372
#
# Epoch 00239: val_accuracy did not improve from 0.88372
#
# Epoch 00240: val_accuracy did not improve from 0.88372
#
# Epoch 00241: val_accuracy did not improve from 0.88372
#
# Epoch 00242: val_accuracy did not improve from 0.88372
#
# Epoch 00243: val_accuracy did not improve from 0.88372
#
# Epoch 00244: val_accuracy did not improve from 0.88372
#
# Epoch 00245: val_accuracy did not improve from 0.88372
#
# Epoch 00246: val_accuracy did not improve from 0.88372
#
# Epoch 00247: val_accuracy did not improve from 0.88372
#
# Epoch 00248: val_accuracy did not improve from 0.88372
#
# Epoch 00249: val_accuracy did not improve from 0.88372
#
# Epoch 00250: val_accuracy did not improve from 0.88372
#
# Epoch 00251: val_accuracy did not improve from 0.88372
#
# Epoch 00252: val_accuracy did not improve from 0.88372
#
# Epoch 00253: val_accuracy did not improve from 0.88372
#
# Epoch 00254: val_accuracy did not improve from 0.88372
#
# Epoch 00255: val_accuracy did not improve from 0.88372
#
# Epoch 00256: val_accuracy did not improve from 0.88372
#
# Epoch 00257: val_accuracy did not improve from 0.88372
#
# Epoch 00258: val_accuracy did not improve from 0.88372
#
# Epoch 00259: val_accuracy did not improve from 0.88372
#
# Epoch 00260: val_accuracy did not improve from 0.88372
#
# Epoch 00261: val_accuracy did not improve from 0.88372
#
# Epoch 00262: val_accuracy did not improve from 0.88372
#
# Epoch 00263: val_accuracy did not improve from 0.88372
#
# Epoch 00264: val_accuracy did not improve from 0.88372
#
# Epoch 00265: val_accuracy did not improve from 0.88372
#
# Epoch 00266: val_accuracy did not improve from 0.88372
#
# Epoch 00267: val_accuracy did not improve from 0.88372
#
# Epoch 00268: val_accuracy did not improve from 0.88372
#
# Epoch 00269: val_accuracy did not improve from 0.88372
#
# Epoch 00270: val_accuracy did not improve from 0.88372
#
# Epoch 00271: val_accuracy did not improve from 0.88372
#
# Epoch 00272: val_accuracy did not improve from 0.88372
#
# Epoch 00273: val_accuracy did not improve from 0.88372
#
# Epoch 00274: val_accuracy did not improve from 0.88372
#
# Epoch 00275: val_accuracy did not improve from 0.88372
#
# Epoch 00276: val_accuracy did not improve from 0.88372
#
# Epoch 00277: val_accuracy did not improve from 0.88372
#
# Epoch 00278: val_accuracy did not improve from 0.88372
#
# Epoch 00279: val_accuracy did not improve from 0.88372
#
# Epoch 00280: val_accuracy did not improve from 0.88372
#
# Epoch 00281: val_accuracy did not improve from 0.88372
#
# Epoch 00282: val_accuracy did not improve from 0.88372
#
# Epoch 00283: val_accuracy did not improve from 0.88372
#
# Epoch 00284: val_accuracy did not improve from 0.88372
#
# Epoch 00285: val_accuracy did not improve from 0.88372
#
# Epoch 00286: val_accuracy did not improve from 0.88372
#
# Epoch 00287: val_accuracy did not improve from 0.88372
#
# Epoch 00288: val_accuracy did not improve from 0.88372
#
# Epoch 00289: val_accuracy did not improve from 0.88372
#
# Epoch 00290: val_accuracy did not improve from 0.88372
#
# Epoch 00291: val_accuracy did not improve from 0.88372
#
# Epoch 00292: val_accuracy did not improve from 0.88372
#
# Epoch 00293: val_accuracy did not improve from 0.88372
#
# Epoch 00294: val_accuracy did not improve from 0.88372
#
# Epoch 00295: val_accuracy did not improve from 0.88372
#
# Epoch 00296: val_accuracy did not improve from 0.88372
#
# Epoch 00297: val_accuracy did not improve from 0.88372
#
# Epoch 00298: val_accuracy did not improve from 0.88372
#
# Epoch 00299: val_accuracy did not improve from 0.88372
#
# Epoch 00300: val_accuracy did not improve from 0.88372
#
# Epoch 00301: val_accuracy did not improve from 0.88372
#
# Epoch 00302: val_accuracy did not improve from 0.88372
#
# Epoch 00303: val_accuracy did not improve from 0.88372
#
# Epoch 00304: val_accuracy did not improve from 0.88372
#
# Epoch 00305: val_accuracy did not improve from 0.88372
#
# Epoch 00306: val_accuracy did not improve from 0.88372
#
# Epoch 00307: val_accuracy did not improve from 0.88372
#
# Epoch 00308: val_accuracy did not improve from 0.88372
#
# Epoch 00309: val_accuracy did not improve from 0.88372
#
# Epoch 00310: val_accuracy did not improve from 0.88372
#
# Epoch 00311: val_accuracy did not improve from 0.88372
#
# Epoch 00312: val_accuracy did not improve from 0.88372
#
# Epoch 00313: val_accuracy did not improve from 0.88372
#
# Epoch 00314: val_accuracy did not improve from 0.88372
#
# Epoch 00315: val_accuracy did not improve from 0.88372
#
# Epoch 00316: val_accuracy did not improve from 0.88372
#
# Epoch 00317: val_accuracy did not improve from 0.88372
#
# Epoch 00318: val_accuracy did not improve from 0.88372
#
# Epoch 00319: val_accuracy did not improve from 0.88372
#
# Epoch 00320: val_accuracy did not improve from 0.88372
#
# Epoch 00321: val_accuracy did not improve from 0.88372
#
# Epoch 00322: val_accuracy did not improve from 0.88372
#
# Epoch 00323: val_accuracy did not improve from 0.88372
#
# Epoch 00324: val_accuracy did not improve from 0.88372
#
# Epoch 00325: val_accuracy did not improve from 0.88372
#
# Epoch 00326: val_accuracy did not improve from 0.88372
#
# Epoch 00327: val_accuracy did not improve from 0.88372
#
# Epoch 00328: val_accuracy did not improve from 0.88372
#
# Epoch 00329: val_accuracy did not improve from 0.88372
#
# Epoch 00330: val_accuracy did not improve from 0.88372
#
# Epoch 00331: val_accuracy did not improve from 0.88372
#
# Epoch 00332: val_accuracy did not improve from 0.88372
#
# Epoch 00333: val_accuracy did not improve from 0.88372
#
# Epoch 00334: val_accuracy did not improve from 0.88372
#
# Epoch 00335: val_accuracy did not improve from 0.88372
#
# Epoch 00336: val_accuracy did not improve from 0.88372
#
# Epoch 00337: val_accuracy did not improve from 0.88372
#
# Epoch 00338: val_accuracy did not improve from 0.88372
#
# Epoch 00339: val_accuracy did not improve from 0.88372
#
# Epoch 00340: val_accuracy did not improve from 0.88372
#
# Epoch 00341: val_accuracy did not improve from 0.88372
#
# Epoch 00342: val_accuracy did not improve from 0.88372
#
# Epoch 00343: val_accuracy did not improve from 0.88372
#
# Epoch 00344: val_accuracy did not improve from 0.88372
#
# Epoch 00345: val_accuracy did not improve from 0.88372
#
# Epoch 00346: val_accuracy did not improve from 0.88372
#
# Epoch 00347: val_accuracy did not improve from 0.88372
#
# Epoch 00348: val_accuracy did not improve from 0.88372
#
# Epoch 00349: val_accuracy did not improve from 0.88372
#
# Epoch 00350: val_accuracy did not improve from 0.88372
#
# Epoch 00351: val_accuracy did not improve from 0.88372
#
# Epoch 00352: val_accuracy did not improve from 0.88372
#
# Epoch 00353: val_accuracy did not improve from 0.88372
#
# Epoch 00354: val_accuracy did not improve from 0.88372
#
# Epoch 00355: val_accuracy did not improve from 0.88372
#
# Epoch 00356: val_accuracy did not improve from 0.88372
#
# Epoch 00357: val_accuracy did not improve from 0.88372
#
# Epoch 00358: val_accuracy did not improve from 0.88372
#
# Epoch 00359: val_accuracy did not improve from 0.88372
#
# Epoch 00360: val_accuracy did not improve from 0.88372
#
# Epoch 00361: val_accuracy did not improve from 0.88372
#
# Epoch 00362: val_accuracy did not improve from 0.88372
#
# Epoch 00363: val_accuracy did not improve from 0.88372
#
# Epoch 00364: val_accuracy did not improve from 0.88372
#
# Epoch 00365: val_accuracy did not improve from 0.88372
#
# Epoch 00366: val_accuracy did not improve from 0.88372
#
# Epoch 00367: val_accuracy did not improve from 0.88372
#
# Epoch 00368: val_accuracy did not improve from 0.88372
#
# Epoch 00369: val_accuracy did not improve from 0.88372
#
# Epoch 00370: val_accuracy did not improve from 0.88372
#
# Epoch 00371: val_accuracy did not improve from 0.88372
#
# Epoch 00372: val_accuracy did not improve from 0.88372
#
# Epoch 00373: val_accuracy did not improve from 0.88372
#
# Epoch 00374: val_accuracy did not improve from 0.88372
#
# Epoch 00375: val_accuracy did not improve from 0.88372
#
# Epoch 00376: val_accuracy did not improve from 0.88372
#
# Epoch 00377: val_accuracy did not improve from 0.88372
#
# Epoch 00378: val_accuracy did not improve from 0.88372
#
# Epoch 00379: val_accuracy did not improve from 0.88372
#
# Epoch 00380: val_accuracy improved from 0.88372 to 0.90698, saving model to best_model.h5
#
# Epoch 00381: val_accuracy did not improve from 0.90698
#
# Epoch 00382: val_accuracy did not improve from 0.90698
#
# Epoch 00383: val_accuracy did not improve from 0.90698
#
# Epoch 00384: val_accuracy did not improve from 0.90698
#
# Epoch 00385: val_accuracy did not improve from 0.90698
#
# Epoch 00386: val_accuracy did not improve from 0.90698
#
# Epoch 00387: val_accuracy did not improve from 0.90698
#
# Epoch 00388: val_accuracy did not improve from 0.90698
#
# Epoch 00389: val_accuracy did not improve from 0.90698
#
# Epoch 00390: val_accuracy did not improve from 0.90698
#
# Epoch 00391: val_accuracy did not improve from 0.90698
#
# Epoch 00392: val_accuracy did not improve from 0.90698
#
# Epoch 00393: val_accuracy did not improve from 0.90698
#
# Epoch 00394: val_accuracy did not improve from 0.90698
#
# Epoch 00395: val_accuracy did not improve from 0.90698
#
# Epoch 00396: val_accuracy did not improve from 0.90698
#
# Epoch 00397: val_accuracy did not improve from 0.90698
#
# Epoch 00398: val_accuracy did not improve from 0.90698
#
# Epoch 00399: val_accuracy did not improve from 0.90698
#
# Epoch 00400: val_accuracy did not improve from 0.90698
#
# Epoch 00401: val_accuracy did not improve from 0.90698
#
# Epoch 00402: val_accuracy did not improve from 0.90698
#
# Epoch 00403: val_accuracy did not improve from 0.90698
#
# Epoch 00404: val_accuracy did not improve from 0.90698
#
# Epoch 00405: val_accuracy did not improve from 0.90698
#
# Epoch 00406: val_accuracy did not improve from 0.90698
#
# Epoch 00407: val_accuracy did not improve from 0.90698
#
# Epoch 00408: val_accuracy did not improve from 0.90698
#
# Epoch 00409: val_accuracy did not improve from 0.90698
#
# Epoch 00410: val_accuracy did not improve from 0.90698
#
# Epoch 00411: val_accuracy did not improve from 0.90698
#
# Epoch 00412: val_accuracy did not improve from 0.90698
#
# Epoch 00413: val_accuracy did not improve from 0.90698
#
# Epoch 00414: val_accuracy did not improve from 0.90698
#
# Epoch 00415: val_accuracy did not improve from 0.90698
#
# Epoch 00416: val_accuracy did not improve from 0.90698
#
# Epoch 00417: val_accuracy did not improve from 0.90698
#
# Epoch 00418: val_accuracy did not improve from 0.90698
#
# Epoch 00419: val_accuracy did not improve from 0.90698
#
# Epoch 00420: val_accuracy did not improve from 0.90698
#
# Epoch 00421: val_accuracy did not improve from 0.90698
#
# Epoch 00422: val_accuracy did not improve from 0.90698
#
# Epoch 00423: val_accuracy did not improve from 0.90698
#
# Epoch 00424: val_accuracy did not improve from 0.90698
#
# Epoch 00425: val_accuracy did not improve from 0.90698
#
# Epoch 00426: val_accuracy did not improve from 0.90698
#
# Epoch 00427: val_accuracy did not improve from 0.90698
#
# Epoch 00428: val_accuracy did not improve from 0.90698
#
# Epoch 00429: val_accuracy did not improve from 0.90698
#
# Epoch 00430: val_accuracy did not improve from 0.90698
#
# Epoch 00431: val_accuracy did not improve from 0.90698
#
# Epoch 00432: val_accuracy did not improve from 0.90698
#
# Epoch 00433: val_accuracy did not improve from 0.90698
#
# Epoch 00434: val_accuracy did not improve from 0.90698
#
# Epoch 00435: val_accuracy did not improve from 0.90698
#
# Epoch 00436: val_accuracy did not improve from 0.90698
#
# Epoch 00437: val_accuracy did not improve from 0.90698
#
# Epoch 00438: val_accuracy did not improve from 0.90698
#
# Epoch 00439: val_accuracy did not improve from 0.90698
#
# Epoch 00440: val_accuracy did not improve from 0.90698
#
# Epoch 00441: val_accuracy did not improve from 0.90698
#
# Epoch 00442: val_accuracy did not improve from 0.90698
#
# Epoch 00443: val_accuracy did not improve from 0.90698
#
# Epoch 00444: val_accuracy did not improve from 0.90698
#
# Epoch 00445: val_accuracy did not improve from 0.90698
#
# Epoch 00446: val_accuracy did not improve from 0.90698
#
# Epoch 00447: val_accuracy did not improve from 0.90698
#
# Epoch 00448: val_accuracy did not improve from 0.90698
#
# Epoch 00449: val_accuracy did not improve from 0.90698
#
# Epoch 00450: val_accuracy did not improve from 0.90698
#
# Epoch 00451: val_accuracy did not improve from 0.90698
#
# Epoch 00452: val_accuracy did not improve from 0.90698
#
# Epoch 00453: val_accuracy did not improve from 0.90698
#
# Epoch 00454: val_accuracy did not improve from 0.90698
#
# Epoch 00455: val_accuracy did not improve from 0.90698
#
# Epoch 00456: val_accuracy did not improve from 0.90698
#
# Epoch 00457: val_accuracy did not improve from 0.90698
#
# Epoch 00458: val_accuracy did not improve from 0.90698
#
# Epoch 00459: val_accuracy did not improve from 0.90698
#
# Epoch 00460: val_accuracy did not improve from 0.90698
#
# Epoch 00461: val_accuracy did not improve from 0.90698
#
# Epoch 00462: val_accuracy did not improve from 0.90698
#
# Epoch 00463: val_accuracy did not improve from 0.90698
#
# Epoch 00464: val_accuracy did not improve from 0.90698
#
# Epoch 00465: val_accuracy did not improve from 0.90698
#
# Epoch 00466: val_accuracy did not improve from 0.90698
#
# Epoch 00467: val_accuracy did not improve from 0.90698
#
# Epoch 00468: val_accuracy did not improve from 0.90698
#
# Epoch 00469: val_accuracy did not improve from 0.90698
#
# Epoch 00470: val_accuracy did not improve from 0.90698
#
# Epoch 00471: val_accuracy did not improve from 0.90698
#
# Epoch 00472: val_accuracy did not improve from 0.90698
#
# Epoch 00473: val_accuracy did not improve from 0.90698
#
# Epoch 00474: val_accuracy did not improve from 0.90698
#
# Epoch 00475: val_accuracy did not improve from 0.90698
#
# Epoch 00476: val_accuracy did not improve from 0.90698
#
# Epoch 00477: val_accuracy did not improve from 0.90698
#
# Epoch 00478: val_accuracy did not improve from 0.90698
#
# Epoch 00479: val_accuracy did not improve from 0.90698
# Epoch 00479: early stopping

# %%
saved_model = load_model('best_model.h5')

# %%
_, test_acc = saved_model.evaluate(x_test, y_test, verbose=0)
print('Test: %.3f' % ( test_acc))
# Out:
# Test: 0.756

# %%
plt.figure(figsize = (10,7))
plt.plot(history.history['accuracy'], color = 'blue')
plt.plot(history.history['val_accuracy'], color = 'red')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.figure(figsize = (10,7))
plt.plot(history.history['loss'], color = 'blue')
plt.plot(history.history['val_loss'], color = 'red')
plt.ylim((0,1))
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# Parameters
# The parameters in this neural network were here were:
#
# Activation layers
#
# First layer of tanh with 512 nodes, having 512*8 weights and 512 biases
#
# Second layer of sigmoid with 256 nodes, having 512*256 weights and 256 biases
#
# Third layer of tanh with 64 nodes, having 256*64 weights and 64 biases
#
# Fourth layer of relu with 32 nodes, having 64*32 weights and 32 biases
#
# Fifth layer of tanh with 16 nodes, having 32*16 weights and 16 biases
#
# Output layer of sigmoid with 1 node, having 16*1 weights and 1 biase.

# %%
from sklearn.datasets import fetch_covtype
forest = fetch_covtype()
# Out:
# Downloading https://ndownloader.figshare.com/files/5976039

# %%
x_fetch_covtype = forest.data
y_fetch_covtype = forest.target
X = pd.DataFrame(x_fetch_covtype)
Y = pd.DataFrame(y_fetch_covtype)
print(X.shape)
print(Y.shape)
# Out:
# (581012, 54)
# (581012, 1)

# %%
cormat = X.corr()
fig, ax = plt.subplots(figsize = [50,50])
sns.heatmap(data = cormat, annot=True)
plt.show()

# %%
Y = to_categorical(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.05)
print("x_train_shape"+str(x_train.shape))
print("y_train_shape"+str(y_train.shape))
print("x_test_shape"+str(x_test.shape))
print("y_test_shape"+str(y_test.shape))
# Out:
# x_train_shape(551961, 54)
# y_train_shape(551961, 8, 2)
# x_test_shape(29051, 54)
# y_test_shape(29051, 8, 2)

# %%
nn = models.Sequential()
nn.add(layers.Dense(512, activation="relu",input_shape=(41, )))
nn.add(layers.Dense(256, activation="relu"))
nn.add(layers.Dense(64, activation="relu"))
nn.add(layers.Dense(32, activation="relu"))
nn.add(layers.Dense(16, activation="relu"))
nn.add(layers.Dense(23, activation="softmax"))

nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 512)               21504
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_16 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_17 (Dense)             (None, 23)                391
# =================================================================
# Total params: 172,279
# Trainable params: 172,279
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(optimizer="rmsprop",
           loss='categorical_crossentropy',
           metrics = ['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=150)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = nn.fit(x_train,y_train, epochs=5000, batch_size = 5000, validation_split=0.05, verbose=0, callbacks=[es, mc])

# %%
_, test_acc = saved_model.evaluate(x_test, y_test, verbose=0)
print('Test: %.3f' % ( test_acc))

# %%
plt.figure(figsize = (10,7))
plt.plot(history.history['accuracy'], color = 'blue')
plt.plot(history.history['val_accuracy'], color = 'red')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.figure(figsize = (10,7))
plt.plot(history.history['loss'], color = 'blue')
plt.plot(history.history['val_loss'], color = 'red')
plt.ylim((0,1))
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Dataset: Breast Cancer

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()

# %%
X = cancer.data
Y = cancer.target
X = pd.DataFrame(X)
Y = pd.DataFrame(Y)
print(X.shape)
print(Y.shape)
# Out:
# (569, 30)
# (569, 1)

# %%
sc = StandardScaler()
X = pd.DataFrame(sc.fit_transform(X))

# %%
cormat = X.corr()
fig, ax = plt.subplots(figsize = [30,30])
sns.heatmap(data = cormat, annot=True)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.05)
print("x_train_shape"+str(x_train.shape))
print("y_train_shape"+str(y_train.shape))
print("x_test_shape"+str(x_test.shape))
print("y_test_shape"+str(y_test.shape))
# Out:
# x_train_shape(540, 30)
# y_train_shape(540, 1)
# x_test_shape(29, 30)
# y_test_shape(29, 1)

# %%
nn = models.Sequential()
nn.add(layers.Dense(512, activation="tanh",input_shape=(30, )))
nn.add(layers.Dense(256, activation="sigmoid"))
nn.add(layers.Dense(64, activation="tanh"))
nn.add(layers.Dense(32, activation="relu"))
nn.add(layers.Dense(16, activation="tanh"))
nn.add(layers.Dense(1, activation="sigmoid"))

nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 512)               15872
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_22 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 166,273
# Trainable params: 166,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(optimizer="rmsprop",
           loss='binary_crossentropy',
           metrics = ['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=300)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = nn.fit(x_train,y_train, epochs=5000, batch_size = 5000, validation_split=0.05, verbose=0, callbacks=[es, mc])
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 02501: val_accuracy did not improve from 1.00000
#
# Epoch 02502: val_accuracy did not improve from 1.00000
#
# Epoch 02503: val_accuracy did not improve from 1.00000
#
# Epoch 02504: val_accuracy did not improve from 1.00000
#
# Epoch 02505: val_accuracy did not improve from 1.00000
#
# Epoch 02506: val_accuracy did not improve from 1.00000
#
# Epoch 02507: val_accuracy did not improve from 1.00000
#
# Epoch 02508: val_accuracy did not improve from 1.00000
#
# Epoch 02509: val_accuracy did not improve from 1.00000
#
# Epoch 02510: val_accuracy did not improve from 1.00000
#
# Epoch 02511: val_accuracy did not improve from 1.00000
#
# Epoch 02512: val_accuracy did not improve from 1.00000
#
# Epoch 02513: val_accuracy did not improve from 1.00000
#
# Epoch 02514: val_accuracy did not improve from 1.00000
#
# Epoch 02515: val_accuracy did not improve from 1.00000
#
# Epoch 02516: val_accuracy did not improve from 1.00000
#
# Epoch 02517: val_accuracy did not improve from 1.00000
#
# Epoch 02518: val_accuracy did not improve from 1.00000
#
# Epoch 02519: val_accuracy did not improve from 1.00000
#
# Epoch 02520: val_accuracy did not improve from 1.00000
#
# Epoch 02521: val_accuracy did not improve from 1.00000
#
# Epoch 02522: val_accuracy did not improve from 1.00000
#
# Epoch 02523: val_accuracy did not improve from 1.00000
#
# Epoch 02524: val_accuracy did not improve from 1.00000
#
# Epoch 02525: val_accuracy did not improve from 1.00000
#
# Epoch 02526: val_accuracy did not improve from 1.00000
#
# Epoch 02527: val_accuracy did not improve from 1.00000
#
# Epoch 02528: val_accuracy did not improve from 1.00000
#
# Epoch 02529: val_accuracy did not improve from 1.00000
#
# Epoch 02530: val_accuracy did not improve from 1.00000
#
# Epoch 02531: val_accuracy did not improve from 1.00000
#
# Epoch 02532: val_accuracy did not improve from 1.00000
#
# Epoch 02533: val_accuracy did not improve from 1.00000
#
# Epoch 02534: val_accuracy did not improve from 1.00000
#
# Epoch 02535: val_accuracy did not improve from 1.00000
#
# Epoch 02536: val_accuracy did not improve from 1.00000
#
# Epoch 02537: val_accuracy did not improve from 1.00000
#
# Epoch 02538: val_accuracy did not improve from 1.00000
#
# Epoch 02539: val_accuracy did not improve from 1.00000
#
# Epoch 02540: val_accuracy did not improve from 1.00000
#
# Epoch 02541: val_accuracy did not improve from 1.00000
#
# Epoch 02542: val_accuracy did not improve from 1.00000
#
# Epoch 02543: val_accuracy did not improve from 1.00000
#
# Epoch 02544: val_accuracy did not improve from 1.00000
#
# Epoch 02545: val_accuracy did not improve from 1.00000
#
# Epoch 02546: val_accuracy did not improve from 1.00000
#
# Epoch 02547: val_accuracy did not improve from 1.00000
#
# Epoch 02548: val_accuracy did not improve from 1.00000
#
# Epoch 02549: val_accuracy did not improve from 1.00000
#
# Epoch 02550: val_accuracy did not improve from 1.00000
#
# Epoch 02551: val_accuracy did not improve from 1.00000
#
# Epoch 02552: val_accuracy did not improve from 1.00000
#
# Epoch 02553: val_accuracy did not improve from 1.00000
#
# Epoch 02554: val_accuracy did not improve from 1.00000
#
# Epoch 02555: val_accuracy did not improve from 1.00000
#
# Epoch 02556: val_accuracy did not improve from 1.00000
#
# Epoch 02557: val_accuracy did not improve from 1.00000
#
# Epoch 02558: val_accuracy did not improve from 1.00000
#
# Epoch 02559: val_accuracy did not improve from 1.00000
#
# Epoch 02560: val_accuracy did not improve from 1.00000
#
# Epoch 02561: val_accuracy did not improve from 1.00000
#
# Epoch 02562: val_accuracy did not improve from 1.00000
#
# Epoch 02563: val_accuracy did not improve from 1.00000
#
# Epoch 02564: val_accuracy did not improve from 1.00000
#
# Epoch 02565: val_accuracy did not improve from 1.00000
#
# Epoch 02566: val_accuracy did not improve from 1.00000
#
# Epoch 02567: val_accuracy did not improve from 1.00000
#
# Epoch 02568: val_accuracy did not improve from 1.00000
#
# Epoch 02569: val_accuracy did not improve from 1.00000
#
# Epoch 02570: val_accuracy did not improve from 1.00000
#
# Epoch 02571: val_accuracy did not improve from 1.00000
#
# Epoch 02572: val_accuracy did not improve from 1.00000
#
# Epoch 02573: val_accuracy did not improve from 1.00000
#
# Epoch 02574: val_accuracy did not improve from 1.00000
#
# Epoch 02575: val_accuracy did not improve from 1.00000
#
# Epoch 02576: val_accuracy did not improve from 1.00000
#
# Epoch 02577: val_accuracy did not improve from 1.00000
#
# Epoch 02578: val_accuracy did not improve from 1.00000
#
# Epoch 02579: val_accuracy did not improve from 1.00000
#
# Epoch 02580: val_accuracy did not improve from 1.00000
#
# Epoch 02581: val_accuracy did not improve from 1.00000
#
# Epoch 02582: val_accuracy did not improve from 1.00000
#
# Epoch 02583: val_accuracy did not improve from 1.00000
#
# Epoch 02584: val_accuracy did not improve from 1.00000
#
# Epoch 02585: val_accuracy did not improve from 1.00000
#
# Epoch 02586: val_accuracy did not improve from 1.00000
#
# Epoch 02587: val_accuracy did not improve from 1.00000
#
# Epoch 02588: val_accuracy did not improve from 1.00000
#
# Epoch 02589: val_accuracy did not improve from 1.00000
#
# Epoch 02590: val_accuracy did not improve from 1.00000
#
# Epoch 02591: val_accuracy did not improve from 1.00000
#
# Epoch 02592: val_accuracy did not improve from 1.00000
#
# Epoch 02593: val_accuracy did not improve from 1.00000
#
# Epoch 02594: val_accuracy did not improve from 1.00000
#
# Epoch 02595: val_accuracy did not improve from 1.00000
#
# Epoch 02596: val_accuracy did not improve from 1.00000
#
# Epoch 02597: val_accuracy did not improve from 1.00000
#
# Epoch 02598: val_accuracy did not improve from 1.00000
#
# Epoch 02599: val_accuracy did not improve from 1.00000
#
# Epoch 02600: val_accuracy did not improve from 1.00000
#
# Epoch 02601: val_accuracy did not improve from 1.00000
#
# Epoch 02602: val_accuracy did not improve from 1.00000
#
# Epoch 02603: val_accuracy did not improve from 1.00000
#
# Epoch 02604: val_accuracy did not improve from 1.00000
#
# Epoch 02605: val_accuracy did not improve from 1.00000
#
# Epoch 02606: val_accuracy did not improve from 1.00000
#
# Epoch 02607: val_accuracy did not improve from 1.00000
#
# Epoch 02608: val_accuracy did not improve from 1.00000
#
# Epoch 02609: val_accuracy did not improve from 1.00000
#
# Epoch 02610: val_accuracy did not improve from 1.00000
#
# Epoch 02611: val_accuracy did not improve from 1.00000
#
# Epoch 02612: val_accuracy did not improve from 1.00000
#
# Epoch 02613: val_accuracy did not improve from 1.00000
#
# Epoch 02614: val_accuracy did not improve from 1.00000
#
# Epoch 02615: val_accuracy did not improve from 1.00000
#
# Epoch 02616: val_accuracy did not improve from 1.00000
#
# Epoch 02617: val_accuracy did not improve from 1.00000
#
# Epoch 02618: val_accuracy did not improve from 1.00000
#
# Epoch 02619: val_accuracy did not improve from 1.00000
#
# Epoch 02620: val_accuracy did not improve from 1.00000
#
# Epoch 02621: val_accuracy did not improve from 1.00000
#
# Epoch 02622: val_accuracy did not improve from 1.00000
#
# Epoch 02623: val_accuracy did not improve from 1.00000
#
# Epoch 02624: val_accuracy did not improve from 1.00000
#
# Epoch 02625: val_accuracy did not improve from 1.00000
#
# Epoch 02626: val_accuracy did not improve from 1.00000
#
# Epoch 02627: val_accuracy did not improve from 1.00000
#
# Epoch 02628: val_accuracy did not improve from 1.00000
#
# Epoch 02629: val_accuracy did not improve from 1.00000
#
# Epoch 02630: val_accuracy did not improve from 1.00000
#
# Epoch 02631: val_accuracy did not improve from 1.00000
#
# Epoch 02632: val_accuracy did not improve from 1.00000
#
# Epoch 02633: val_accuracy did not improve from 1.00000
#
# Epoch 02634: val_accuracy did not improve from 1.00000
#
# Epoch 02635: val_accuracy did not improve from 1.00000
#
# Epoch 02636: val_accuracy did not improve from 1.00000
#
# Epoch 02637: val_accuracy did not improve from 1.00000
#
# Epoch 02638: val_accuracy did not improve from 1.00000
#
# Epoch 02639: val_accuracy did not improve from 1.00000
#
# Epoch 02640: val_accuracy did not improve from 1.00000
#
# Epoch 02641: val_accuracy did not improve from 1.00000
#
# Epoch 02642: val_accuracy did not improve from 1.00000
#
# Epoch 02643: val_accuracy did not improve from 1.00000
#
# Epoch 02644: val_accuracy did not improve from 1.00000
#
# Epoch 02645: val_accuracy did not improve from 1.00000
#
# Epoch 02646: val_accuracy did not improve from 1.00000
#
# Epoch 02647: val_accuracy did not improve from 1.00000
#
# Epoch 02648: val_accuracy did not improve from 1.00000
#
# Epoch 02649: val_accuracy did not improve from 1.00000
#
# Epoch 02650: val_accuracy did not improve from 1.00000
#
# Epoch 02651: val_accuracy did not improve from 1.00000
#
# Epoch 02652: val_accuracy did not improve from 1.00000
#
# Epoch 02653: val_accuracy did not improve from 1.00000
#
# Epoch 02654: val_accuracy did not improve from 1.00000
#
# Epoch 02655: val_accuracy did not improve from 1.00000
#
# Epoch 02656: val_accuracy did not improve from 1.00000
#
# Epoch 02657: val_accuracy did not improve from 1.00000
#
# Epoch 02658: val_accuracy did not improve from 1.00000
#
# Epoch 02659: val_accuracy did not improve from 1.00000
#
# Epoch 02660: val_accuracy did not improve from 1.00000
#
# Epoch 02661: val_accuracy did not improve from 1.00000
#
# Epoch 02662: val_accuracy did not improve from 1.00000
#
# Epoch 02663: val_accuracy did not improve from 1.00000
#
# Epoch 02664: val_accuracy did not improve from 1.00000
#
# Epoch 02665: val_accuracy did not improve from 1.00000
#
# Epoch 02666: val_accuracy did not improve from 1.00000
#
# Epoch 02667: val_accuracy did not improve from 1.00000
#
# Epoch 02668: val_accuracy did not improve from 1.00000
#
# Epoch 02669: val_accuracy did not improve from 1.00000
#
# Epoch 02670: val_accuracy did not improve from 1.00000
#
# Epoch 02671: val_accuracy did not improve from 1.00000
#
# Epoch 02672: val_accuracy did not improve from 1.00000
#
# Epoch 02673: val_accuracy did not improve from 1.00000
#
# Epoch 02674: val_accuracy did not improve from 1.00000
#
# Epoch 02675: val_accuracy did not improve from 1.00000
#
# Epoch 02676: val_accuracy did not improve from 1.00000
#
# Epoch 02677: val_accuracy did not improve from 1.00000
#
# Epoch 02678: val_accuracy did not improve from 1.00000
#
# Epoch 02679: val_accuracy did not improve from 1.00000
#
# Epoch 02680: val_accuracy did not improve from 1.00000
#
# Epoch 02681: val_accuracy did not improve from 1.00000
#
# Epoch 02682: val_accuracy did not improve from 1.00000
#
# Epoch 02683: val_accuracy did not improve from 1.00000
#
# Epoch 02684: val_accuracy did not improve from 1.00000
#
# Epoch 02685: val_accuracy did not improve from 1.00000
#
# Epoch 02686: val_accuracy did not improve from 1.00000
#
# Epoch 02687: val_accuracy did not improve from 1.00000
#
# Epoch 02688: val_accuracy did not improve from 1.00000
#
# Epoch 02689: val_accuracy did not improve from 1.00000
#
# Epoch 02690: val_accuracy did not improve from 1.00000
#
# Epoch 02691: val_accuracy did not improve from 1.00000
#
# Epoch 02692: val_accuracy did not improve from 1.00000
#
# Epoch 02693: val_accuracy did not improve from 1.00000
#
# Epoch 02694: val_accuracy did not improve from 1.00000
#
# Epoch 02695: val_accuracy did not improve from 1.00000
#
# Epoch 02696: val_accuracy did not improve from 1.00000
#
# Epoch 02697: val_accuracy did not improve from 1.00000
#
# Epoch 02698: val_accuracy did not improve from 1.00000
#
# Epoch 02699: val_accuracy did not improve from 1.00000
#
# Epoch 02700: val_accuracy did not improve from 1.00000
#
# Epoch 02701: val_accuracy did not improve from 1.00000
#
# Epoch 02702: val_accuracy did not improve from 1.00000
#
# Epoch 02703: val_accuracy did not improve from 1.00000
#
# Epoch 02704: val_accuracy did not improve from 1.00000
#
# Epoch 02705: val_accuracy did not improve from 1.00000
#
# Epoch 02706: val_accuracy did not improve from 1.00000
#
# Epoch 02707: val_accuracy did not improve from 1.00000
#
# Epoch 02708: val_accuracy did not improve from 1.00000
#
# Epoch 02709: val_accuracy did not improve from 1.00000
#
# Epoch 02710: val_accuracy did not improve from 1.00000
#
# Epoch 02711: val_accuracy did not improve from 1.00000
#
# Epoch 02712: val_accuracy did not improve from 1.00000
#
# Epoch 02713: val_accuracy did not improve from 1.00000
#
# Epoch 02714: val_accuracy did not improve from 1.00000
#
# Epoch 02715: val_accuracy did not improve from 1.00000
#
# Epoch 02716: val_accuracy did not improve from 1.00000
#
# Epoch 02717: val_accuracy did not improve from 1.00000
#
# Epoch 02718: val_accuracy did not improve from 1.00000
#
# Epoch 02719: val_accuracy did not improve from 1.00000
#
# Epoch 02720: val_accuracy did not improve from 1.00000
#
# Epoch 02721: val_accuracy did not improve from 1.00000
#
# Epoch 02722: val_accuracy did not improve from 1.00000
#
# Epoch 02723: val_accuracy did not improve from 1.00000
#
# Epoch 02724: val_accuracy did not improve from 1.00000
#
# Epoch 02725: val_accuracy did not improve from 1.00000
#
# Epoch 02726: val_accuracy did not improve from 1.00000
#
# Epoch 02727: val_accuracy did not improve from 1.00000
#
# Epoch 02728: val_accuracy did not improve from 1.00000
#
# Epoch 02729: val_accuracy did not improve from 1.00000
#
# Epoch 02730: val_accuracy did not improve from 1.00000
#
# Epoch 02731: val_accuracy did not improve from 1.00000
#
# Epoch 02732: val_accuracy did not improve from 1.00000
#
# Epoch 02733: val_accuracy did not improve from 1.00000
#
# Epoch 02734: val_accuracy did not improve from 1.00000
#
# Epoch 02735: val_accuracy did not improve from 1.00000
#
# Epoch 02736: val_accuracy did not improve from 1.00000
#
# Epoch 02737: val_accuracy did not improve from 1.00000
#
# Epoch 02738: val_accuracy did not improve from 1.00000
#
# Epoch 02739: val_accuracy did not improve from 1.00000
#
# Epoch 02740: val_accuracy did not improve from 1.00000
#
# Epoch 02741: val_accuracy did not improve from 1.00000
#
# Epoch 02742: val_accuracy did not improve from 1.00000
#
# Epoch 02743: val_accuracy did not improve from 1.00000
#
# Epoch 02744: val_accuracy did not improve from 1.00000
#
# Epoch 02745: val_accuracy did not improve from 1.00000
#
# Epoch 02746: val_accuracy did not improve from 1.00000
#
# Epoch 02747: val_accuracy did not improve from 1.00000
#
# Epoch 02748: val_accuracy did not improve from 1.00000
#
# Epoch 02749: val_accuracy did not improve from 1.00000
#
# Epoch 02750: val_accuracy did not improve from 1.00000
#
# Epoch 02751: val_accuracy did not improve from 1.00000
#
# Epoch 02752: val_accuracy did not improve from 1.00000
#
# Epoch 02753: val_accuracy did not improve from 1.00000
#
# Epoch 02754: val_accuracy did not improve from 1.00000
#
# Epoch 02755: val_accuracy did not improve from 1.00000
#
# Epoch 02756: val_accuracy did not improve from 1.00000
#
# Epoch 02757: val_accuracy did not improve from 1.00000
#
# Epoch 02758: val_accuracy did not improve from 1.00000
#
# Epoch 02759: val_accuracy did not improve from 1.00000
#
# Epoch 02760: val_accuracy did not improve from 1.00000
#
# Epoch 02761: val_accuracy did not improve from 1.00000
#
# Epoch 02762: val_accuracy did not improve from 1.00000
#
# Epoch 02763: val_accuracy did not improve from 1.00000
#
# Epoch 02764: val_accuracy did not improve from 1.00000
#
# Epoch 02765: val_accuracy did not improve from 1.00000
#
# Epoch 02766: val_accuracy did not improve from 1.00000
#
# Epoch 02767: val_accuracy did not improve from 1.00000
#
# Epoch 02768: val_accuracy did not improve from 1.00000
#
# Epoch 02769: val_accuracy did not improve from 1.00000
#
# Epoch 02770: val_accuracy did not improve from 1.00000
#
# Epoch 02771: val_accuracy did not improve from 1.00000
#
# Epoch 02772: val_accuracy did not improve from 1.00000
#
# Epoch 02773: val_accuracy did not improve from 1.00000
#
# Epoch 02774: val_accuracy did not improve from 1.00000
#
# Epoch 02775: val_accuracy did not improve from 1.00000
#
# Epoch 02776: val_accuracy did not improve from 1.00000
#
# Epoch 02777: val_accuracy did not improve from 1.00000
#
# Epoch 02778: val_accuracy did not improve from 1.00000
#
# Epoch 02779: val_accuracy did not improve from 1.00000
#
# Epoch 02780: val_accuracy did not improve from 1.00000
#
# Epoch 02781: val_accuracy did not improve from 1.00000
#
# Epoch 02782: val_accuracy did not improve from 1.00000
#
# Epoch 02783: val_accuracy did not improve from 1.00000
#
# Epoch 02784: val_accuracy did not improve from 1.00000
#
# Epoch 02785: val_accuracy did not improve from 1.00000
#
# Epoch 02786: val_accuracy did not improve from 1.00000
#
# Epoch 02787: val_accuracy did not improve from 1.00000
#
# Epoch 02788: val_accuracy did not improve from 1.00000
#
# Epoch 02789: val_accuracy did not improve from 1.00000
#
# Epoch 02790: val_accuracy did not improve from 1.00000
#
# Epoch 02791: val_accuracy did not improve from 1.00000
#
# Epoch 02792: val_accuracy did not improve from 1.00000
#
# Epoch 02793: val_accuracy did not improve from 1.00000
#
# Epoch 02794: val_accuracy did not improve from 1.00000
#
# Epoch 02795: val_accuracy did not improve from 1.00000
#
# Epoch 02796: val_accuracy did not improve from 1.00000
#
# Epoch 02797: val_accuracy did not improve from 1.00000
#
# Epoch 02798: val_accuracy did not improve from 1.00000
#
# Epoch 02799: val_accuracy did not improve from 1.00000
#
# Epoch 02800: val_accuracy did not improve from 1.00000
#
# Epoch 02801: val_accuracy did not improve from 1.00000
#
# Epoch 02802: val_accuracy did not improve from 1.00000
#
# Epoch 02803: val_accuracy did not improve from 1.00000
#
# Epoch 02804: val_accuracy did not improve from 1.00000
#
# Epoch 02805: val_accuracy did not improve from 1.00000
#
# Epoch 02806: val_accuracy did not improve from 1.00000
#
# Epoch 02807: val_accuracy did not improve from 1.00000
#
# Epoch 02808: val_accuracy did not improve from 1.00000
#
# Epoch 02809: val_accuracy did not improve from 1.00000
#
# Epoch 02810: val_accuracy did not improve from 1.00000
#
# Epoch 02811: val_accuracy did not improve from 1.00000
#
# Epoch 02812: val_accuracy did not improve from 1.00000
#
# Epoch 02813: val_accuracy did not improve from 1.00000
#
# Epoch 02814: val_accuracy did not improve from 1.00000
#
# Epoch 02815: val_accuracy did not improve from 1.00000
#
# Epoch 02816: val_accuracy did not improve from 1.00000
#
# Epoch 02817: val_accuracy did not improve from 1.00000
#
# Epoch 02818: val_accuracy did not improve from 1.00000
#
# Epoch 02819: val_accuracy did not improve from 1.00000
#
# Epoch 02820: val_accuracy did not improve from 1.00000
#
# Epoch 02821: val_accuracy did not improve from 1.00000
#
# Epoch 02822: val_accuracy did not improve from 1.00000
#
# Epoch 02823: val_accuracy did not improve from 1.00000
#
# Epoch 02824: val_accuracy did not improve from 1.00000
#
# Epoch 02825: val_accuracy did not improve from 1.00000
#
# Epoch 02826: val_accuracy did not improve from 1.00000
#
# Epoch 02827: val_accuracy did not improve from 1.00000
#
# Epoch 02828: val_accuracy did not improve from 1.00000
#
# Epoch 02829: val_accuracy did not improve from 1.00000
#
# Epoch 02830: val_accuracy did not improve from 1.00000
#
# Epoch 02831: val_accuracy did not improve from 1.00000
#
# Epoch 02832: val_accuracy did not improve from 1.00000
#
# Epoch 02833: val_accuracy did not improve from 1.00000
#
# Epoch 02834: val_accuracy did not improve from 1.00000
#
# Epoch 02835: val_accuracy did not improve from 1.00000
#
# Epoch 02836: val_accuracy did not improve from 1.00000
#
# Epoch 02837: val_accuracy did not improve from 1.00000
#
# Epoch 02838: val_accuracy did not improve from 1.00000
#
# Epoch 02839: val_accuracy did not improve from 1.00000
#
# Epoch 02840: val_accuracy did not improve from 1.00000
#
# Epoch 02841: val_accuracy did not improve from 1.00000
#
# Epoch 02842: val_accuracy did not improve from 1.00000
#
# Epoch 02843: val_accuracy did not improve from 1.00000
#
# Epoch 02844: val_accuracy did not improve from 1.00000
#
# Epoch 02845: val_accuracy did not improve from 1.00000
#
# Epoch 02846: val_accuracy did not improve from 1.00000
#
# Epoch 02847: val_accuracy did not improve from 1.00000
#
# Epoch 02848: val_accuracy did not improve from 1.00000
#
# Epoch 02849: val_accuracy did not improve from 1.00000
#
# Epoch 02850: val_accuracy did not improve from 1.00000
#
# Epoch 02851: val_accuracy did not improve from 1.00000
#
# Epoch 02852: val_accuracy did not improve from 1.00000
#
# Epoch 02853: val_accuracy did not improve from 1.00000
#
# Epoch 02854: val_accuracy did not improve from 1.00000
#
# Epoch 02855: val_accuracy did not improve from 1.00000
#
# Epoch 02856: val_accuracy did not improve from 1.00000
#
# Epoch 02857: val_accuracy did not improve from 1.00000
#
# Epoch 02858: val_accuracy did not improve from 1.00000
#
# Epoch 02859: val_accuracy did not improve from 1.00000
#
# Epoch 02860: val_accuracy did not improve from 1.00000
#
# Epoch 02861: val_accuracy did not improve from 1.00000
#
# Epoch 02862: val_accuracy did not improve from 1.00000
#
# Epoch 02863: val_accuracy did not improve from 1.00000
#
# Epoch 02864: val_accuracy did not improve from 1.00000
#
# Epoch 02865: val_accuracy did not improve from 1.00000
#
# Epoch 02866: val_accuracy did not improve from 1.00000
#
# Epoch 02867: val_accuracy did not improve from 1.00000
#
# Epoch 02868: val_accuracy did not improve from 1.00000
#
# Epoch 02869: val_accuracy did not improve from 1.00000
#
# Epoch 02870: val_accuracy did not improve from 1.00000
#
# Epoch 02871: val_accuracy did not improve from 1.00000
#
# Epoch 02872: val_accuracy did not improve from 1.00000
#
# Epoch 02873: val_accuracy did not improve from 1.00000
#
# Epoch 02874: val_accuracy did not improve from 1.00000
#
# Epoch 02875: val_accuracy did not improve from 1.00000
#
# Epoch 02876: val_accuracy did not improve from 1.00000
#
# Epoch 02877: val_accuracy did not improve from 1.00000
#
# Epoch 02878: val_accuracy did not improve from 1.00000
#
# Epoch 02879: val_accuracy did not improve from 1.00000
#
# Epoch 02880: val_accuracy did not improve from 1.00000
#
# Epoch 02881: val_accuracy did not improve from 1.00000
#
# Epoch 02882: val_accuracy did not improve from 1.00000
#
# Epoch 02883: val_accuracy did not improve from 1.00000
#
# Epoch 02884: val_accuracy did not improve from 1.00000
#
# Epoch 02885: val_accuracy did not improve from 1.00000
#
# Epoch 02886: val_accuracy did not improve from 1.00000
#
# Epoch 02887: val_accuracy did not improve from 1.00000
#
# Epoch 02888: val_accuracy did not improve from 1.00000
#
# Epoch 02889: val_accuracy did not improve from 1.00000
#
# Epoch 02890: val_accuracy did not improve from 1.00000
#
# Epoch 02891: val_accuracy did not improve from 1.00000
#
# Epoch 02892: val_accuracy did not improve from 1.00000
#
# Epoch 02893: val_accuracy did not improve from 1.00000
#
# Epoch 02894: val_accuracy did not improve from 1.00000
#
# Epoch 02895: val_accuracy did not improve from 1.00000
#
# Epoch 02896: val_accuracy did not improve from 1.00000
#
# Epoch 02897: val_accuracy did not improve from 1.00000
#
# Epoch 02898: val_accuracy did not improve from 1.00000
#
# Epoch 02899: val_accuracy did not improve from 1.00000
#
# Epoch 02900: val_accuracy did not improve from 1.00000
#
# Epoch 02901: val_accuracy did not improve from 1.00000
#
# Epoch 02902: val_accuracy did not improve from 1.00000
#
# Epoch 02903: val_accuracy did not improve from 1.00000
#
# Epoch 02904: val_accuracy did not improve from 1.00000
#
# Epoch 02905: val_accuracy did not improve from 1.00000
#
# Epoch 02906: val_accuracy did not improve from 1.00000
#
# Epoch 02907: val_accuracy did not improve from 1.00000
#
# Epoch 02908: val_accuracy did not improve from 1.00000
#
# Epoch 02909: val_accuracy did not improve from 1.00000
#
# Epoch 02910: val_accuracy did not improve from 1.00000
#
# Epoch 02911: val_accuracy did not improve from 1.00000
#
# Epoch 02912: val_accuracy did not improve from 1.00000
#
# Epoch 02913: val_accuracy did not improve from 1.00000
#
# Epoch 02914: val_accuracy did not improve from 1.00000
#
# Epoch 02915: val_accuracy did not improve from 1.00000
#
# Epoch 02916: val_accuracy did not improve from 1.00000
#
# Epoch 02917: val_accuracy did not improve from 1.00000
#
# Epoch 02918: val_accuracy did not improve from 1.00000
#
# Epoch 02919: val_accuracy did not improve from 1.00000
#
# Epoch 02920: val_accuracy did not improve from 1.00000
#
# Epoch 02921: val_accuracy did not improve from 1.00000
#
# Epoch 02922: val_accuracy did not improve from 1.00000
#
# Epoch 02923: val_accuracy did not improve from 1.00000
#
# Epoch 02924: val_accuracy did not improve from 1.00000
#
# Epoch 02925: val_accuracy did not improve from 1.00000
#
# Epoch 02926: val_accuracy did not improve from 1.00000
#
# Epoch 02927: val_accuracy did not improve from 1.00000
#
# Epoch 02928: val_accuracy did not improve from 1.00000
#
# Epoch 02929: val_accuracy did not improve from 1.00000
#
# Epoch 02930: val_accuracy did not improve from 1.00000
#
# Epoch 02931: val_accuracy did not improve from 1.00000
#
# Epoch 02932: val_accuracy did not improve from 1.00000
#
# Epoch 02933: val_accuracy did not improve from 1.00000
#
# Epoch 02934: val_accuracy did not improve from 1.00000
#
# Epoch 02935: val_accuracy did not improve from 1.00000
#
# Epoch 02936: val_accuracy did not improve from 1.00000
#
# Epoch 02937: val_accuracy did not improve from 1.00000
#
# Epoch 02938: val_accuracy did not improve from 1.00000
#
# Epoch 02939: val_accuracy did not improve from 1.00000
#
# Epoch 02940: val_accuracy did not improve from 1.00000
#
# Epoch 02941: val_accuracy did not improve from 1.00000
#
# Epoch 02942: val_accuracy did not improve from 1.00000
#
# Epoch 02943: val_accuracy did not improve from 1.00000
#
# Epoch 02944: val_accuracy did not improve from 1.00000
#
# Epoch 02945: val_accuracy did not improve from 1.00000
#
# Epoch 02946: val_accuracy did not improve from 1.00000
#
# Epoch 02947: val_accuracy did not improve from 1.00000
#
# Epoch 02948: val_accuracy did not improve from 1.00000
#
# Epoch 02949: val_accuracy did not improve from 1.00000
#
# Epoch 02950: val_accuracy did not improve from 1.00000
#
# Epoch 02951: val_accuracy did not improve from 1.00000
#
# Epoch 02952: val_accuracy did not improve from 1.00000
#
# Epoch 02953: val_accuracy did not improve from 1.00000
#
# Epoch 02954: val_accuracy did not improve from 1.00000
#
# Epoch 02955: val_accuracy did not improve from 1.00000
#
# Epoch 02956: val_accuracy did not improve from 1.00000
#
# Epoch 02957: val_accuracy did not improve from 1.00000
#
# Epoch 02958: val_accuracy did not improve from 1.00000
#
# Epoch 02959: val_accuracy did not improve from 1.00000
#
# Epoch 02960: val_accuracy did not improve from 1.00000
#
# Epoch 02961: val_accuracy did not improve from 1.00000
#
# Epoch 02962: val_accuracy did not improve from 1.00000
#
# Epoch 02963: val_accuracy did not improve from 1.00000
#
# Epoch 02964: val_accuracy did not improve from 1.00000
#
# Epoch 02965: val_accuracy did not improve from 1.00000
#
# Epoch 02966: val_accuracy did not improve from 1.00000
#
# Epoch 02967: val_accuracy did not improve from 1.00000
#
# Epoch 02968: val_accuracy did not improve from 1.00000
#
# Epoch 02969: val_accuracy did not improve from 1.00000
#
# Epoch 02970: val_accuracy did not improve from 1.00000
#
# Epoch 02971: val_accuracy did not improve from 1.00000
#
# Epoch 02972: val_accuracy did not improve from 1.00000
#
# Epoch 02973: val_accuracy did not improve from 1.00000
#
# Epoch 02974: val_accuracy did not improve from 1.00000
#
# Epoch 02975: val_accuracy did not improve from 1.00000
#
# Epoch 02976: val_accuracy did not improve from 1.00000
#
# Epoch 02977: val_accuracy did not improve from 1.00000
#
# Epoch 02978: val_accuracy did not improve from 1.00000
#
# Epoch 02979: val_accuracy did not improve from 1.00000
#
# Epoch 02980: val_accuracy did not improve from 1.00000
#
# Epoch 02981: val_accuracy did not improve from 1.00000
#
# Epoch 02982: val_accuracy did not improve from 1.00000
#
# Epoch 02983: val_accuracy did not improve from 1.00000
#
# Epoch 02984: val_accuracy did not improve from 1.00000
#
# Epoch 02985: val_accuracy did not improve from 1.00000
#
# Epoch 02986: val_accuracy did not improve from 1.00000
#
# Epoch 02987: val_accuracy did not improve from 1.00000
#
# Epoch 02988: val_accuracy did not improve from 1.00000
#
# Epoch 02989: val_accuracy did not improve from 1.00000
#
# Epoch 02990: val_accuracy did not improve from 1.00000
#
# Epoch 02991: val_accuracy did not improve from 1.00000
#
# Epoch 02992: val_accuracy did not improve from 1.00000
#
# Epoch 02993: val_accuracy did not improve from 1.00000
#
# Epoch 02994: val_accuracy did not improve from 1.00000
#
# Epoch 02995: val_accuracy did not improve from 1.00000
#
# Epoch 02996: val_accuracy did not improve from 1.00000
#
# Epoch 02997: val_accuracy did not improve from 1.00000
#
# Epoch 02998: val_accuracy did not improve from 1.00000
#
# Epoch 02999: val_accuracy did not improve from 1.00000
#
# Epoch 03000: val_accuracy did not improve from 1.00000
#
# Epoch 03001: val_accuracy did not improve from 1.00000
#
# Epoch 03002: val_accuracy did not improve from 1.00000
#
# Epoch 03003: val_accuracy did not improve from 1.00000
#
# Epoch 03004: val_accuracy did not improve from 1.00000
#
# Epoch 03005: val_accuracy did not improve from 1.00000
#
# Epoch 03006: val_accuracy did not improve from 1.00000
#
# Epoch 03007: val_accuracy did not improve from 1.00000
#
# Epoch 03008: val_accuracy did not improve from 1.00000
#
# Epoch 03009: val_accuracy did not improve from 1.00000
#
# Epoch 03010: val_accuracy did not improve from 1.00000
#
# Epoch 03011: val_accuracy did not improve from 1.00000
#
# Epoch 03012: val_accuracy did not improve from 1.00000
#
# Epoch 03013: val_accuracy did not improve from 1.00000
#
# Epoch 03014: val_accuracy did not improve from 1.00000
#
# Epoch 03015: val_accuracy did not improve from 1.00000
#
# Epoch 03016: val_accuracy did not improve from 1.00000
#
# Epoch 03017: val_accuracy did not improve from 1.00000
#
# Epoch 03018: val_accuracy did not improve from 1.00000
#
# Epoch 03019: val_accuracy did not improve from 1.00000
#
# Epoch 03020: val_accuracy did not improve from 1.00000
#
# Epoch 03021: val_accuracy did not improve from 1.00000
#
# Epoch 03022: val_accuracy did not improve from 1.00000
#
# Epoch 03023: val_accuracy did not improve from 1.00000
#
# Epoch 03024: val_accuracy did not improve from 1.00000
#
# Epoch 03025: val_accuracy did not improve from 1.00000
#
# Epoch 03026: val_accuracy did not improve from 1.00000
#
# Epoch 03027: val_accuracy did not improve from 1.00000
#
# Epoch 03028: val_accuracy did not improve from 1.00000
#
# Epoch 03029: val_accuracy did not improve from 1.00000
#
# Epoch 03030: val_accuracy did not improve from 1.00000
#
# Epoch 03031: val_accuracy did not improve from 1.00000
#
# Epoch 03032: val_accuracy did not improve from 1.00000
#
# Epoch 03033: val_accuracy did not improve from 1.00000
#
# Epoch 03034: val_accuracy did not improve from 1.00000
#
# Epoch 03035: val_accuracy did not improve from 1.00000
#
# Epoch 03036: val_accuracy did not improve from 1.00000
#
# Epoch 03037: val_accuracy did not improve from 1.00000
#
# Epoch 03038: val_accuracy did not improve from 1.00000
#
# Epoch 03039: val_accuracy did not improve from 1.00000
#
# Epoch 03040: val_accuracy did not improve from 1.00000
#
# Epoch 03041: val_accuracy did not improve from 1.00000
#
# Epoch 03042: val_accuracy did not improve from 1.00000
#
# Epoch 03043: val_accuracy did not improve from 1.00000
#
# Epoch 03044: val_accuracy did not improve from 1.00000
#
# Epoch 03045: val_accuracy did not improve from 1.00000
#
# Epoch 03046: val_accuracy did not improve from 1.00000
#
# Epoch 03047: val_accuracy did not improve from 1.00000
#
# Epoch 03048: val_accuracy did not improve from 1.00000
#
# Epoch 03049: val_accuracy did not improve from 1.00000
#
# Epoch 03050: val_accuracy did not improve from 1.00000
#
# Epoch 03051: val_accuracy did not improve from 1.00000
#
# Epoch 03052: val_accuracy did not improve from 1.00000
#
# Epoch 03053: val_accuracy did not improve from 1.00000
#
# Epoch 03054: val_accuracy did not improve from 1.00000
#
# Epoch 03055: val_accuracy did not improve from 1.00000
#
# Epoch 03056: val_accuracy did not improve from 1.00000
#
# Epoch 03057: val_accuracy did not improve from 1.00000
#
# Epoch 03058: val_accuracy did not improve from 1.00000
#
# Epoch 03059: val_accuracy did not improve from 1.00000
#
# Epoch 03060: val_accuracy did not improve from 1.00000
#
# Epoch 03061: val_accuracy did not improve from 1.00000
#
# Epoch 03062: val_accuracy did not improve from 1.00000
#
# Epoch 03063: val_accuracy did not improve from 1.00000
#
# Epoch 03064: val_accuracy did not improve from 1.00000
#
# Epoch 03065: val_accuracy did not improve from 1.00000
#
# Epoch 03066: val_accuracy did not improve from 1.00000
#
# Epoch 03067: val_accuracy did not improve from 1.00000
#
# Epoch 03068: val_accuracy did not improve from 1.00000
#
# Epoch 03069: val_accuracy did not improve from 1.00000
#
# Epoch 03070: val_accuracy did not improve from 1.00000
#
# Epoch 03071: val_accuracy did not improve from 1.00000
#
# Epoch 03072: val_accuracy did not improve from 1.00000
#
# Epoch 03073: val_accuracy did not improve from 1.00000
#
# Epoch 03074: val_accuracy did not improve from 1.00000
#
# Epoch 03075: val_accuracy did not improve from 1.00000
#
# Epoch 03076: val_accuracy did not improve from 1.00000
#
# Epoch 03077: val_accuracy did not improve from 1.00000
#
# Epoch 03078: val_accuracy did not improve from 1.00000
#
# Epoch 03079: val_accuracy did not improve from 1.00000
#
# Epoch 03080: val_accuracy did not improve from 1.00000
#
# Epoch 03081: val_accuracy did not improve from 1.00000
#
# Epoch 03082: val_accuracy did not improve from 1.00000
#
# Epoch 03083: val_accuracy did not improve from 1.00000
#
# Epoch 03084: val_accuracy did not improve from 1.00000
#
# Epoch 03085: val_accuracy did not improve from 1.00000
#
# Epoch 03086: val_accuracy did not improve from 1.00000
#
# Epoch 03087: val_accuracy did not improve from 1.00000
#
# Epoch 03088: val_accuracy did not improve from 1.00000
#
# Epoch 03089: val_accuracy did not improve from 1.00000
#
# Epoch 03090: val_accuracy did not improve from 1.00000
#
# Epoch 03091: val_accuracy did not improve from 1.00000
#
# Epoch 03092: val_accuracy did not improve from 1.00000
#
# Epoch 03093: val_accuracy did not improve from 1.00000
#
# Epoch 03094: val_accuracy did not improve from 1.00000
#
# Epoch 03095: val_accuracy did not improve from 1.00000
#
# Epoch 03096: val_accuracy did not improve from 1.00000
#
# Epoch 03097: val_accuracy did not improve from 1.00000
#
# Epoch 03098: val_accuracy did not improve from 1.00000
#
# Epoch 03099: val_accuracy did not improve from 1.00000
#
# Epoch 03100: val_accuracy did not improve from 1.00000
#
# Epoch 03101: val_accuracy did not improve from 1.00000
#
# Epoch 03102: val_accuracy did not improve from 1.00000
#
# Epoch 03103: val_accuracy did not improve from 1.00000
#
# Epoch 03104: val_accuracy did not improve from 1.00000
#
# Epoch 03105: val_accuracy did not improve from 1.00000
#
# Epoch 03106: val_accuracy did not improve from 1.00000
#
# Epoch 03107: val_accuracy did not improve from 1.00000
#
# Epoch 03108: val_accuracy did not improve from 1.00000
#
# Epoch 03109: val_accuracy did not improve from 1.00000
#
# Epoch 03110: val_accuracy did not improve from 1.00000
#
# Epoch 03111: val_accuracy did not improve from 1.00000
#
# Epoch 03112: val_accuracy did not improve from 1.00000
#
# Epoch 03113: val_accuracy did not improve from 1.00000
#
# Epoch 03114: val_accuracy did not improve from 1.00000
#
# Epoch 03115: val_accuracy did not improve from 1.00000
#
# Epoch 03116: val_accuracy did not improve from 1.00000
#
# Epoch 03117: val_accuracy did not improve from 1.00000
#
# Epoch 03118: val_accuracy did not improve from 1.00000
#
# Epoch 03119: val_accuracy did not improve from 1.00000
#
# Epoch 03120: val_accuracy did not improve from 1.00000
#
# Epoch 03121: val_accuracy did not improve from 1.00000
#
# Epoch 03122: val_accuracy did not improve from 1.00000
#
# Epoch 03123: val_accuracy did not improve from 1.00000
#
# Epoch 03124: val_accuracy did not improve from 1.00000
#
# Epoch 03125: val_accuracy did not improve from 1.00000
#
# Epoch 03126: val_accuracy did not improve from 1.00000
#
# Epoch 03127: val_accuracy did not improve from 1.00000
#
# Epoch 03128: val_accuracy did not improve from 1.00000
#
# Epoch 03129: val_accuracy did not improve from 1.00000
#
# Epoch 03130: val_accuracy did not improve from 1.00000
#
# Epoch 03131: val_accuracy did not improve from 1.00000
#
# Epoch 03132: val_accuracy did not improve from 1.00000
#
# Epoch 03133: val_accuracy did not improve from 1.00000
#
# Epoch 03134: val_accuracy did not improve from 1.00000
#
# Epoch 03135: val_accuracy did not improve from 1.00000
#
# Epoch 03136: val_accuracy did not improve from 1.00000
#
# Epoch 03137: val_accuracy did not improve from 1.00000
#
# Epoch 03138: val_accuracy did not improve from 1.00000
#
# Epoch 03139: val_accuracy did not improve from 1.00000
#
# Epoch 03140: val_accuracy did not improve from 1.00000
#
# Epoch 03141: val_accuracy did not improve from 1.00000
#
# Epoch 03142: val_accuracy did not improve from 1.00000
#
# Epoch 03143: val_accuracy did not improve from 1.00000
#
# Epoch 03144: val_accuracy did not improve from 1.00000
#
# Epoch 03145: val_accuracy did not improve from 1.00000
#
# Epoch 03146: val_accuracy did not improve from 1.00000
#
# Epoch 03147: val_accuracy did not improve from 1.00000
#
# Epoch 03148: val_accuracy did not improve from 1.00000
#
# Epoch 03149: val_accuracy did not improve from 1.00000
#
# Epoch 03150: val_accuracy did not improve from 1.00000
#
# Epoch 03151: val_accuracy did not improve from 1.00000
#
# Epoch 03152: val_accuracy did not improve from 1.00000
#
# Epoch 03153: val_accuracy did not improve from 1.00000
#
# Epoch 03154: val_accuracy did not improve from 1.00000
#
# Epoch 03155: val_accuracy did not improve from 1.00000
#
# Epoch 03156: val_accuracy did not improve from 1.00000
#
# Epoch 03157: val_accuracy did not improve from 1.00000
#
# Epoch 03158: val_accuracy did not improve from 1.00000
#
# Epoch 03159: val_accuracy did not improve from 1.00000
#
# Epoch 03160: val_accuracy did not improve from 1.00000
#
# Epoch 03161: val_accuracy did not improve from 1.00000
#
# Epoch 03162: val_accuracy did not improve from 1.00000
#
# Epoch 03163: val_accuracy did not improve from 1.00000
#
# Epoch 03164: val_accuracy did not improve from 1.00000
#
# Epoch 03165: val_accuracy did not improve from 1.00000
#
# Epoch 03166: val_accuracy did not improve from 1.00000
#
# Epoch 03167: val_accuracy did not improve from 1.00000
#
# Epoch 03168: val_accuracy did not improve from 1.00000
#
# Epoch 03169: val_accuracy did not improve from 1.00000
#
# Epoch 03170: val_accuracy did not improve from 1.00000
#
# Epoch 03171: val_accuracy did not improve from 1.00000
#
# Epoch 03172: val_accuracy did not improve from 1.00000
#
# Epoch 03173: val_accuracy did not improve from 1.00000
#
# Epoch 03174: val_accuracy did not improve from 1.00000
#
# Epoch 03175: val_accuracy did not improve from 1.00000
#
# Epoch 03176: val_accuracy did not improve from 1.00000
#
# Epoch 03177: val_accuracy did not improve from 1.00000
#
# Epoch 03178: val_accuracy did not improve from 1.00000
#
# Epoch 03179: val_accuracy did not improve from 1.00000
#
# Epoch 03180: val_accuracy did not improve from 1.00000
#
# Epoch 03181: val_accuracy did not improve from 1.00000
#
# Epoch 03182: val_accuracy did not improve from 1.00000
#
# Epoch 03183: val_accuracy did not improve from 1.00000
#
# Epoch 03184: val_accuracy did not improve from 1.00000
#
# Epoch 03185: val_accuracy did not improve from 1.00000
#
# Epoch 03186: val_accuracy did not improve from 1.00000
#
# Epoch 03187: val_accuracy did not improve from 1.00000
#
# Epoch 03188: val_accuracy did not improve from 1.00000
#
# Epoch 03189: val_accuracy did not improve from 1.00000
#
# Epoch 03190: val_accuracy did not improve from 1.00000
#
# Epoch 03191: val_accuracy did not improve from 1.00000
#
# Epoch 03192: val_accuracy did not improve from 1.00000
#
# Epoch 03193: val_accuracy did not improve from 1.00000
#
# Epoch 03194: val_accuracy did not improve from 1.00000
#
# Epoch 03195: val_accuracy did not improve from 1.00000
#
# Epoch 03196: val_accuracy did not improve from 1.00000
#
# Epoch 03197: val_accuracy did not improve from 1.00000
#
# Epoch 03198: val_accuracy did not improve from 1.00000
#
# Epoch 03199: val_accuracy did not improve from 1.00000
#
# Epoch 03200: val_accuracy did not improve from 1.00000
#
# Epoch 03201: val_accuracy did not improve from 1.00000
#
# Epoch 03202: val_accuracy did not improve from 1.00000
#
# Epoch 03203: val_accuracy did not improve from 1.00000
#
# Epoch 03204: val_accuracy did not improve from 1.00000
#
# Epoch 03205: val_accuracy did not improve from 1.00000
#
# Epoch 03206: val_accuracy did not improve from 1.00000
#
# Epoch 03207: val_accuracy did not improve from 1.00000
#
# Epoch 03208: val_accuracy did not improve from 1.00000
#
# Epoch 03209: val_accuracy did not improve from 1.00000
#
# Epoch 03210: val_accuracy did not improve from 1.00000
#
# Epoch 03211: val_accuracy did not improve from 1.00000
#
# Epoch 03212: val_accuracy did not improve from 1.00000
#
# Epoch 03213: val_accuracy did not improve from 1.00000
#
# Epoch 03214: val_accuracy did not improve from 1.00000
#
# Epoch 03215: val_accuracy did not improve from 1.00000
#
# Epoch 03216: val_accuracy did not improve from 1.00000
#
# Epoch 03217: val_accuracy did not improve from 1.00000
#
# Epoch 03218: val_accuracy did not improve from 1.00000
#
# Epoch 03219: val_accuracy did not improve from 1.00000
#
# Epoch 03220: val_accuracy did not improve from 1.00000
#
# Epoch 03221: val_accuracy did not improve from 1.00000
#
# Epoch 03222: val_accuracy did not improve from 1.00000
#
# Epoch 03223: val_accuracy did not improve from 1.00000
#
# Epoch 03224: val_accuracy did not improve from 1.00000
#
# Epoch 03225: val_accuracy did not improve from 1.00000
#
# Epoch 03226: val_accuracy did not improve from 1.00000
#
# Epoch 03227: val_accuracy did not improve from 1.00000
#
# Epoch 03228: val_accuracy did not improve from 1.00000
#
# Epoch 03229: val_accuracy did not improve from 1.00000
#
# Epoch 03230: val_accuracy did not improve from 1.00000
#
# Epoch 03231: val_accuracy did not improve from 1.00000
#
# Epoch 03232: val_accuracy did not improve from 1.00000
#
# Epoch 03233: val_accuracy did not improve from 1.00000
#
# Epoch 03234: val_accuracy did not improve from 1.00000
#
# Epoch 03235: val_accuracy did not improve from 1.00000
#
# Epoch 03236: val_accuracy did not improve from 1.00000
#
# Epoch 03237: val_accuracy did not improve from 1.00000
#
# Epoch 03238: val_accuracy did not improve from 1.00000
#
# Epoch 03239: val_accuracy did not improve from 1.00000
#
# Epoch 03240: val_accuracy did not improve from 1.00000
#
# Epoch 03241: val_accuracy did not improve from 1.00000
#
# Epoch 03242: val_accuracy did not improve from 1.00000
#
# Epoch 03243: val_accuracy did not improve from 1.00000
#
# Epoch 03244: val_accuracy did not improve from 1.00000
#
# Epoch 03245: val_accuracy did not improve from 1.00000
#
# Epoch 03246: val_accuracy did not improve from 1.00000
#
# Epoch 03247: val_accuracy did not improve from 1.00000
#
# Epoch 03248: val_accuracy did not improve from 1.00000
#
# Epoch 03249: val_accuracy did not improve from 1.00000
#
# Epoch 03250: val_accuracy did not improve from 1.00000
#
# Epoch 03251: val_accuracy did not improve from 1.00000
#
# Epoch 03252: val_accuracy did not improve from 1.00000
#
# Epoch 03253: val_accuracy did not improve from 1.00000
#
# Epoch 03254: val_accuracy did not improve from 1.00000
#
# Epoch 03255: val_accuracy did not improve from 1.00000
#
# Epoch 03256: val_accuracy did not improve from 1.00000
#
# Epoch 03257: val_accuracy did not improve from 1.00000
#
# Epoch 03258: val_accuracy did not improve from 1.00000
#
# Epoch 03259: val_accuracy did not improve from 1.00000
#
# Epoch 03260: val_accuracy did not improve from 1.00000
#
# Epoch 03261: val_accuracy did not improve from 1.00000
#
# Epoch 03262: val_accuracy did not improve from 1.00000
#
# Epoch 03263: val_accuracy did not improve from 1.00000
#
# Epoch 03264: val_accuracy did not improve from 1.00000
#
# Epoch 03265: val_accuracy did not improve from 1.00000
#
# Epoch 03266: val_accuracy did not improve from 1.00000
#
# Epoch 03267: val_accuracy did not improve from 1.00000
#
# Epoch 03268: val_accuracy did not improve from 1.00000
#
# Epoch 03269: val_accuracy did not improve from 1.00000
#
# Epoch 03270: val_accuracy did not improve from 1.00000
#
# Epoch 03271: val_accuracy did not improve from 1.00000
#
# Epoch 03272: val_accuracy did not improve from 1.00000
#
# Epoch 03273: val_accuracy did not improve from 1.00000
#
# Epoch 03274: val_accuracy did not improve from 1.00000
#
# Epoch 03275: val_accuracy did not improve from 1.00000
#
# Epoch 03276: val_accuracy did not improve from 1.00000
#
# Epoch 03277: val_accuracy did not improve from 1.00000
#
# Epoch 03278: val_accuracy did not improve from 1.00000
#
# Epoch 03279: val_accuracy did not improve from 1.00000
#
# Epoch 03280: val_accuracy did not improve from 1.00000
#
# Epoch 03281: val_accuracy did not improve from 1.00000
#
# Epoch 03282: val_accuracy did not improve from 1.00000
#
# Epoch 03283: val_accuracy did not improve from 1.00000
#
# Epoch 03284: val_accuracy did not improve from 1.00000
#
# Epoch 03285: val_accuracy did not improve from 1.00000
#
# Epoch 03286: val_accuracy did not improve from 1.00000
#
# Epoch 03287: val_accuracy did not improve from 1.00000
#
# Epoch 03288: val_accuracy did not improve from 1.00000
#
# Epoch 03289: val_accuracy did not improve from 1.00000
#
# Epoch 03290: val_accuracy did not improve from 1.00000
#
# Epoch 03291: val_accuracy did not improve from 1.00000
#
# Epoch 03292: val_accuracy did not improve from 1.00000
#
# Epoch 03293: val_accuracy did not improve from 1.00000
#
# Epoch 03294: val_accuracy did not improve from 1.00000
#
# Epoch 03295: val_accuracy did not improve from 1.00000
#
# Epoch 03296: val_accuracy did not improve from 1.00000
#
# Epoch 03297: val_accuracy did not improve from 1.00000
#
# Epoch 03298: val_accuracy did not improve from 1.00000
#
# Epoch 03299: val_accuracy did not improve from 1.00000
#
# Epoch 03300: val_accuracy did not improve from 1.00000
#
# Epoch 03301: val_accuracy did not improve from 1.00000
#
# Epoch 03302: val_accuracy did not improve from 1.00000
#
# Epoch 03303: val_accuracy did not improve from 1.00000
#
# Epoch 03304: val_accuracy did not improve from 1.00000
#
# Epoch 03305: val_accuracy did not improve from 1.00000
#
# Epoch 03306: val_accuracy did not improve from 1.00000
#
# Epoch 03307: val_accuracy did not improve from 1.00000
#
# Epoch 03308: val_accuracy did not improve from 1.00000
#
# Epoch 03309: val_accuracy did not improve from 1.00000
#
# Epoch 03310: val_accuracy did not improve from 1.00000
#
# Epoch 03311: val_accuracy did not improve from 1.00000
#
# Epoch 03312: val_accuracy did not improve from 1.00000
#
# Epoch 03313: val_accuracy did not improve from 1.00000
#
# Epoch 03314: val_accuracy did not improve from 1.00000
#
# Epoch 03315: val_accuracy did not improve from 1.00000
#
# Epoch 03316: val_accuracy did not improve from 1.00000
#
# Epoch 03317: val_accuracy did not improve from 1.00000
#
# Epoch 03318: val_accuracy did not improve from 1.00000
#
# Epoch 03319: val_accuracy did not improve from 1.00000
#
# Epoch 03320: val_accuracy did not improve from 1.00000
#
# Epoch 03321: val_accuracy did not improve from 1.00000
#
# Epoch 03322: val_accuracy did not improve from 1.00000
#
# Epoch 03323: val_accuracy did not improve from 1.00000
#
# Epoch 03324: val_accuracy did not improve from 1.00000
#
# Epoch 03325: val_accuracy did not improve from 1.00000
#
# Epoch 03326: val_accuracy did not improve from 1.00000
#
# Epoch 03327: val_accuracy did not improve from 1.00000
#
# Epoch 03328: val_accuracy did not improve from 1.00000
#
# Epoch 03329: val_accuracy did not improve from 1.00000
#
# Epoch 03330: val_accuracy did not improve from 1.00000
#
# Epoch 03331: val_accuracy did not improve from 1.00000
#
# Epoch 03332: val_accuracy did not improve from 1.00000
#
# Epoch 03333: val_accuracy did not improve from 1.00000
#
# Epoch 03334: val_accuracy did not improve from 1.00000
#
# Epoch 03335: val_accuracy did not improve from 1.00000
#
# Epoch 03336: val_accuracy did not improve from 1.00000
#
# Epoch 03337: val_accuracy did not improve from 1.00000
#
# Epoch 03338: val_accuracy did not improve from 1.00000
#
# Epoch 03339: val_accuracy did not improve from 1.00000
#
# Epoch 03340: val_accuracy did not improve from 1.00000
#
# Epoch 03341: val_accuracy did not improve from 1.00000
#
# Epoch 03342: val_accuracy did not improve from 1.00000
#
# Epoch 03343: val_accuracy did not improve from 1.00000
#
# Epoch 03344: val_accuracy did not improve from 1.00000
#
# Epoch 03345: val_accuracy did not improve from 1.00000
#
# Epoch 03346: val_accuracy did not improve from 1.00000
#
# Epoch 03347: val_accuracy did not improve from 1.00000
#
# Epoch 03348: val_accuracy did not improve from 1.00000
#
# Epoch 03349: val_accuracy did not improve from 1.00000
#
# Epoch 03350: val_accuracy did not improve from 1.00000
#
# Epoch 03351: val_accuracy did not improve from 1.00000
#
# Epoch 03352: val_accuracy did not improve from 1.00000
#
# Epoch 03353: val_accuracy did not improve from 1.00000
#
# Epoch 03354: val_accuracy did not improve from 1.00000
#
# Epoch 03355: val_accuracy did not improve from 1.00000
#
# Epoch 03356: val_accuracy did not improve from 1.00000
#
# ...
#
# Epoch 04716: val_accuracy did not improve from 1.00000
#
# Epoch 04717: val_accuracy did not improve from 1.00000
#
# Epoch 04718: val_accuracy did not improve from 1.00000
#
# Epoch 04719: val_accuracy did not improve from 1.00000
#
# Epoch 04720: val_accuracy did not improve from 1.00000
#
# Epoch 04721: val_accuracy did not improve from 1.00000
#
# Epoch 04722: val_accuracy did not improve from 1.00000
#
# Epoch 04723: val_accuracy did not improve from 1.00000
#
# Epoch 04724: val_accuracy did not improve from 1.00000
#
# Epoch 04725: val_accuracy did not improve from 1.00000
#
# Epoch 04726: val_accuracy did not improve from 1.00000
#
# Epoch 04727: val_accuracy did not improve from 1.00000
#
# Epoch 04728: val_accuracy did not improve from 1.00000
#
# Epoch 04729: val_accuracy did not improve from 1.00000
#
# Epoch 04730: val_accuracy did not improve from 1.00000
#
# Epoch 04731: val_accuracy did not improve from 1.00000
#
# Epoch 04732: val_accuracy did not improve from 1.00000
#
# Epoch 04733: val_accuracy did not improve from 1.00000
#
# Epoch 04734: val_accuracy did not improve from 1.00000
#
# Epoch 04735: val_accuracy did not improve from 1.00000
#
# Epoch 04736: val_accuracy did not improve from 1.00000
#
# Epoch 04737: val_accuracy did not improve from 1.00000
#
# Epoch 04738: val_accuracy did not improve from 1.00000
#
# Epoch 04739: val_accuracy did not improve from 1.00000
#
# Epoch 04740: val_accuracy did not improve from 1.00000
#
# Epoch 04741: val_accuracy did not improve from 1.00000
#
# Epoch 04742: val_accuracy did not improve from 1.00000
#
# Epoch 04743: val_accuracy did not improve from 1.00000
#
# Epoch 04744: val_accuracy did not improve from 1.00000
#
# Epoch 04745: val_accuracy did not improve from 1.00000
#
# Epoch 04746: val_accuracy did not improve from 1.00000
#
# Epoch 04747: val_accuracy did not improve from 1.00000
#
# Epoch 04748: val_accuracy did not improve from 1.00000
#
# Epoch 04749: val_accuracy did not improve from 1.00000
#
# Epoch 04750: val_accuracy did not improve from 1.00000
#
# Epoch 04751: val_accuracy did not improve from 1.00000
#
# Epoch 04752: val_accuracy did not improve from 1.00000
#
# Epoch 04753: val_accuracy did not improve from 1.00000
#
# Epoch 04754: val_accuracy did not improve from 1.00000
#
# Epoch 04755: val_accuracy did not improve from 1.00000
#
# Epoch 04756: val_accuracy did not improve from 1.00000
#
# Epoch 04757: val_accuracy did not improve from 1.00000
#
# Epoch 04758: val_accuracy did not improve from 1.00000
#
# Epoch 04759: val_accuracy did not improve from 1.00000
#
# Epoch 04760: val_accuracy did not improve from 1.00000
#
# Epoch 04761: val_accuracy did not improve from 1.00000
#
# Epoch 04762: val_accuracy did not improve from 1.00000
#
# Epoch 04763: val_accuracy did not improve from 1.00000
#
# Epoch 04764: val_accuracy did not improve from 1.00000
#
# Epoch 04765: val_accuracy did not improve from 1.00000
#
# Epoch 04766: val_accuracy did not improve from 1.00000
#
# Epoch 04767: val_accuracy did not improve from 1.00000
#
# Epoch 04768: val_accuracy did not improve from 1.00000
#
# Epoch 04769: val_accuracy did not improve from 1.00000
#
# Epoch 04770: val_accuracy did not improve from 1.00000
#
# Epoch 04771: val_accuracy did not improve from 1.00000
#
# Epoch 04772: val_accuracy did not improve from 1.00000
#
# Epoch 04773: val_accuracy did not improve from 1.00000
#
# Epoch 04774: val_accuracy did not improve from 1.00000
#
# Epoch 04775: val_accuracy did not improve from 1.00000
#
# Epoch 04776: val_accuracy did not improve from 1.00000
#
# Epoch 04777: val_accuracy did not improve from 1.00000
#
# Epoch 04778: val_accuracy did not improve from 1.00000
#
# Epoch 04779: val_accuracy did not improve from 1.00000
#
# Epoch 04780: val_accuracy did not improve from 1.00000
#
# Epoch 04781: val_accuracy did not improve from 1.00000
#
# Epoch 04782: val_accuracy did not improve from 1.00000
#
# Epoch 04783: val_accuracy did not improve from 1.00000
#
# Epoch 04784: val_accuracy did not improve from 1.00000
#
# Epoch 04785: val_accuracy did not improve from 1.00000
#
# Epoch 04786: val_accuracy did not improve from 1.00000
#
# Epoch 04787: val_accuracy did not improve from 1.00000
#
# Epoch 04788: val_accuracy did not improve from 1.00000
#
# Epoch 04789: val_accuracy did not improve from 1.00000
#
# Epoch 04790: val_accuracy did not improve from 1.00000
#
# Epoch 04791: val_accuracy did not improve from 1.00000
#
# Epoch 04792: val_accuracy did not improve from 1.00000
#
# Epoch 04793: val_accuracy did not improve from 1.00000
#
# Epoch 04794: val_accuracy did not improve from 1.00000
#
# Epoch 04795: val_accuracy did not improve from 1.00000
#
# Epoch 04796: val_accuracy did not improve from 1.00000
#
# Epoch 04797: val_accuracy did not improve from 1.00000
#
# Epoch 04798: val_accuracy did not improve from 1.00000
#
# Epoch 04799: val_accuracy did not improve from 1.00000
#
# Epoch 04800: val_accuracy did not improve from 1.00000
#
# Epoch 04801: val_accuracy did not improve from 1.00000
#
# Epoch 04802: val_accuracy did not improve from 1.00000
#
# Epoch 04803: val_accuracy did not improve from 1.00000
#
# Epoch 04804: val_accuracy did not improve from 1.00000
#
# Epoch 04805: val_accuracy did not improve from 1.00000
#
# Epoch 04806: val_accuracy did not improve from 1.00000
#
# Epoch 04807: val_accuracy did not improve from 1.00000
#
# Epoch 04808: val_accuracy did not improve from 1.00000
#
# Epoch 04809: val_accuracy did not improve from 1.00000
#
# Epoch 04810: val_accuracy did not improve from 1.00000
#
# Epoch 04811: val_accuracy did not improve from 1.00000
#
# Epoch 04812: val_accuracy did not improve from 1.00000
#
# Epoch 04813: val_accuracy did not improve from 1.00000
#
# Epoch 04814: val_accuracy did not improve from 1.00000
#
# Epoch 04815: val_accuracy did not improve from 1.00000
#
# Epoch 04816: val_accuracy did not improve from 1.00000
#
# Epoch 04817: val_accuracy did not improve from 1.00000
#
# Epoch 04818: val_accuracy did not improve from 1.00000
#
# Epoch 04819: val_accuracy did not improve from 1.00000
#
# Epoch 04820: val_accuracy did not improve from 1.00000
#
# Epoch 04821: val_accuracy did not improve from 1.00000
#
# Epoch 04822: val_accuracy did not improve from 1.00000
#
# Epoch 04823: val_accuracy did not improve from 1.00000
#
# Epoch 04824: val_accuracy did not improve from 1.00000
#
# Epoch 04825: val_accuracy did not improve from 1.00000
#
# Epoch 04826: val_accuracy did not improve from 1.00000
#
# Epoch 04827: val_accuracy did not improve from 1.00000
#
# Epoch 04828: val_accuracy did not improve from 1.00000
#
# Epoch 04829: val_accuracy did not improve from 1.00000
#
# Epoch 04830: val_accuracy did not improve from 1.00000
#
# Epoch 04831: val_accuracy did not improve from 1.00000
#
# Epoch 04832: val_accuracy did not improve from 1.00000
#
# Epoch 04833: val_accuracy did not improve from 1.00000
#
# Epoch 04834: val_accuracy did not improve from 1.00000
#
# Epoch 04835: val_accuracy did not improve from 1.00000
#
# Epoch 04836: val_accuracy did not improve from 1.00000
#
# Epoch 04837: val_accuracy did not improve from 1.00000
#
# Epoch 04838: val_accuracy did not improve from 1.00000
#
# Epoch 04839: val_accuracy did not improve from 1.00000
#
# Epoch 04840: val_accuracy did not improve from 1.00000
#
# Epoch 04841: val_accuracy did not improve from 1.00000
#
# Epoch 04842: val_accuracy did not improve from 1.00000
#
# Epoch 04843: val_accuracy did not improve from 1.00000
#
# Epoch 04844: val_accuracy did not improve from 1.00000
#
# Epoch 04845: val_accuracy did not improve from 1.00000
#
# Epoch 04846: val_accuracy did not improve from 1.00000
#
# Epoch 04847: val_accuracy did not improve from 1.00000
#
# Epoch 04848: val_accuracy did not improve from 1.00000
#
# Epoch 04849: val_accuracy did not improve from 1.00000
#
# Epoch 04850: val_accuracy did not improve from 1.00000
#
# Epoch 04851: val_accuracy did not improve from 1.00000
#
# Epoch 04852: val_accuracy did not improve from 1.00000
#
# Epoch 04853: val_accuracy did not improve from 1.00000
#
# Epoch 04854: val_accuracy did not improve from 1.00000
#
# Epoch 04855: val_accuracy did not improve from 1.00000
#
# Epoch 04856: val_accuracy did not improve from 1.00000
#
# Epoch 04857: val_accuracy did not improve from 1.00000
#
# Epoch 04858: val_accuracy did not improve from 1.00000
#
# Epoch 04859: val_accuracy did not improve from 1.00000
#
# Epoch 04860: val_accuracy did not improve from 1.00000
#
# Epoch 04861: val_accuracy did not improve from 1.00000
#
# Epoch 04862: val_accuracy did not improve from 1.00000
#
# Epoch 04863: val_accuracy did not improve from 1.00000
#
# Epoch 04864: val_accuracy did not improve from 1.00000
#
# Epoch 04865: val_accuracy did not improve from 1.00000
#
# Epoch 04866: val_accuracy did not improve from 1.00000
#
# Epoch 04867: val_accuracy did not improve from 1.00000
#
# Epoch 04868: val_accuracy did not improve from 1.00000
#
# Epoch 04869: val_accuracy did not improve from 1.00000
#
# Epoch 04870: val_accuracy did not improve from 1.00000
#
# Epoch 04871: val_accuracy did not improve from 1.00000
#
# Epoch 04872: val_accuracy did not improve from 1.00000
#
# Epoch 04873: val_accuracy did not improve from 1.00000
#
# Epoch 04874: val_accuracy did not improve from 1.00000
#
# Epoch 04875: val_accuracy did not improve from 1.00000
#
# Epoch 04876: val_accuracy did not improve from 1.00000
#
# Epoch 04877: val_accuracy did not improve from 1.00000
#
# Epoch 04878: val_accuracy did not improve from 1.00000
#
# Epoch 04879: val_accuracy did not improve from 1.00000
#
# Epoch 04880: val_accuracy did not improve from 1.00000
#
# Epoch 04881: val_accuracy did not improve from 1.00000
#
# Epoch 04882: val_accuracy did not improve from 1.00000
#
# Epoch 04883: val_accuracy did not improve from 1.00000
#
# Epoch 04884: val_accuracy did not improve from 1.00000
#
# Epoch 04885: val_accuracy did not improve from 1.00000
#
# Epoch 04886: val_accuracy did not improve from 1.00000
#
# Epoch 04887: val_accuracy did not improve from 1.00000
#
# Epoch 04888: val_accuracy did not improve from 1.00000
#
# Epoch 04889: val_accuracy did not improve from 1.00000
#
# Epoch 04890: val_accuracy did not improve from 1.00000
#
# Epoch 04891: val_accuracy did not improve from 1.00000
#
# Epoch 04892: val_accuracy did not improve from 1.00000
#
# Epoch 04893: val_accuracy did not improve from 1.00000
#
# Epoch 04894: val_accuracy did not improve from 1.00000
#
# Epoch 04895: val_accuracy did not improve from 1.00000
#
# Epoch 04896: val_accuracy did not improve from 1.00000
#
# Epoch 04897: val_accuracy did not improve from 1.00000
#
# Epoch 04898: val_accuracy did not improve from 1.00000
#
# Epoch 04899: val_accuracy did not improve from 1.00000
#
# Epoch 04900: val_accuracy did not improve from 1.00000
#
# Epoch 04901: val_accuracy did not improve from 1.00000
#
# Epoch 04902: val_accuracy did not improve from 1.00000
#
# Epoch 04903: val_accuracy did not improve from 1.00000
#
# Epoch 04904: val_accuracy did not improve from 1.00000
#
# Epoch 04905: val_accuracy did not improve from 1.00000
#
# Epoch 04906: val_accuracy did not improve from 1.00000
#
# Epoch 04907: val_accuracy did not improve from 1.00000
#
# Epoch 04908: val_accuracy did not improve from 1.00000
#
# Epoch 04909: val_accuracy did not improve from 1.00000
#
# Epoch 04910: val_accuracy did not improve from 1.00000
#
# Epoch 04911: val_accuracy did not improve from 1.00000
#
# Epoch 04912: val_accuracy did not improve from 1.00000
#
# Epoch 04913: val_accuracy did not improve from 1.00000
#
# Epoch 04914: val_accuracy did not improve from 1.00000
#
# Epoch 04915: val_accuracy did not improve from 1.00000
#
# Epoch 04916: val_accuracy did not improve from 1.00000
#
# Epoch 04917: val_accuracy did not improve from 1.00000
#
# Epoch 04918: val_accuracy did not improve from 1.00000
#
# Epoch 04919: val_accuracy did not improve from 1.00000
#
# Epoch 04920: val_accuracy did not improve from 1.00000
#
# Epoch 04921: val_accuracy did not improve from 1.00000
#
# Epoch 04922: val_accuracy did not improve from 1.00000
#
# Epoch 04923: val_accuracy did not improve from 1.00000
#
# Epoch 04924: val_accuracy did not improve from 1.00000
#
# Epoch 04925: val_accuracy did not improve from 1.00000
#
# Epoch 04926: val_accuracy did not improve from 1.00000
#
# Epoch 04927: val_accuracy did not improve from 1.00000
#
# Epoch 04928: val_accuracy did not improve from 1.00000
#
# Epoch 04929: val_accuracy did not improve from 1.00000
#
# Epoch 04930: val_accuracy did not improve from 1.00000
#
# Epoch 04931: val_accuracy did not improve from 1.00000
#
# Epoch 04932: val_accuracy did not improve from 1.00000
#
# Epoch 04933: val_accuracy did not improve from 1.00000
#
# Epoch 04934: val_accuracy did not improve from 1.00000
#
# Epoch 04935: val_accuracy did not improve from 1.00000
#
# Epoch 04936: val_accuracy did not improve from 1.00000
#
# Epoch 04937: val_accuracy did not improve from 1.00000
#
# Epoch 04938: val_accuracy did not improve from 1.00000
#
# Epoch 04939: val_accuracy did not improve from 1.00000
#
# Epoch 04940: val_accuracy did not improve from 1.00000
#
# Epoch 04941: val_accuracy did not improve from 1.00000
#
# Epoch 04942: val_accuracy did not improve from 1.00000
#
# Epoch 04943: val_accuracy did not improve from 1.00000
#
# Epoch 04944: val_accuracy did not improve from 1.00000
#
# Epoch 04945: val_accuracy did not improve from 1.00000
#
# Epoch 04946: val_accuracy did not improve from 1.00000
#
# Epoch 04947: val_accuracy did not improve from 1.00000
#
# Epoch 04948: val_accuracy did not improve from 1.00000
#
# Epoch 04949: val_accuracy did not improve from 1.00000
#
# Epoch 04950: val_accuracy did not improve from 1.00000
#
# Epoch 04951: val_accuracy did not improve from 1.00000
#
# Epoch 04952: val_accuracy did not improve from 1.00000
#
# Epoch 04953: val_accuracy did not improve from 1.00000
#
# Epoch 04954: val_accuracy did not improve from 1.00000
#
# Epoch 04955: val_accuracy did not improve from 1.00000
#
# Epoch 04956: val_accuracy did not improve from 1.00000
#
# Epoch 04957: val_accuracy did not improve from 1.00000
#
# Epoch 04958: val_accuracy did not improve from 1.00000
#
# Epoch 04959: val_accuracy did not improve from 1.00000
#
# Epoch 04960: val_accuracy did not improve from 1.00000
#
# Epoch 04961: val_accuracy did not improve from 1.00000
#
# Epoch 04962: val_accuracy did not improve from 1.00000
#
# Epoch 04963: val_accuracy did not improve from 1.00000
#
# Epoch 04964: val_accuracy did not improve from 1.00000
#
# Epoch 04965: val_accuracy did not improve from 1.00000
#
# Epoch 04966: val_accuracy did not improve from 1.00000
#
# Epoch 04967: val_accuracy did not improve from 1.00000
#
# Epoch 04968: val_accuracy did not improve from 1.00000
#
# Epoch 04969: val_accuracy did not improve from 1.00000
#
# Epoch 04970: val_accuracy did not improve from 1.00000
#
# Epoch 04971: val_accuracy did not improve from 1.00000
#
# Epoch 04972: val_accuracy did not improve from 1.00000
#
# Epoch 04973: val_accuracy did not improve from 1.00000
#
# Epoch 04974: val_accuracy did not improve from 1.00000
#
# Epoch 04975: val_accuracy did not improve from 1.00000
#
# Epoch 04976: val_accuracy did not improve from 1.00000
#
# Epoch 04977: val_accuracy did not improve from 1.00000
#
# Epoch 04978: val_accuracy did not improve from 1.00000
#
# Epoch 04979: val_accuracy did not improve from 1.00000
#
# Epoch 04980: val_accuracy did not improve from 1.00000
#
# Epoch 04981: val_accuracy did not improve from 1.00000
#
# Epoch 04982: val_accuracy did not improve from 1.00000
#
# Epoch 04983: val_accuracy did not improve from 1.00000
#
# Epoch 04984: val_accuracy did not improve from 1.00000
#
# Epoch 04985: val_accuracy did not improve from 1.00000
#
# Epoch 04986: val_accuracy did not improve from 1.00000
#
# Epoch 04987: val_accuracy did not improve from 1.00000
#
# Epoch 04988: val_accuracy did not improve from 1.00000
#
# Epoch 04989: val_accuracy did not improve from 1.00000
#
# Epoch 04990: val_accuracy did not improve from 1.00000
#
# Epoch 04991: val_accuracy did not improve from 1.00000
#
# Epoch 04992: val_accuracy did not improve from 1.00000
#
# Epoch 04993: val_accuracy did not improve from 1.00000
#
# Epoch 04994: val_accuracy did not improve from 1.00000
#
# Epoch 04995: val_accuracy did not improve from 1.00000
#
# Epoch 04996: val_accuracy did not improve from 1.00000
#
# Epoch 04997: val_accuracy did not improve from 1.00000
#
# Epoch 04998: val_accuracy did not improve from 1.00000
#
# Epoch 04999: val_accuracy did not improve from 1.00000
#
# Epoch 05000: val_accuracy did not improve from 1.00000

# %%
saved_model = load_model('best_model.h5')
_, test_acc = saved_model.evaluate(x_test, y_test, verbose=0)
print('Test: %.3f' % ( test_acc))

# %% [markdown]
# # Plots

# %%
plt.figure(figsize = (10,7))
plt.plot(history.history['accuracy'], color = 'blue')
plt.plot(history.history['val_accuracy'], color = 'red')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.figure(figsize = (10,7))
plt.plot(history.history['loss'], color = 'blue')
plt.plot(history.history['val_loss'], color = 'red')
plt.ylim((0,1))
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Dataset: Load Wine

# %%
from sklearn.datasets import load_wine
wine = load_wine()

# %%
X = wine.data
Y = wine.target
X = pd.DataFrame(X)
Y = pd.DataFrame(Y)
print(X.shape)
print(Y.shape)
# Out:
# (178, 13)
# (178, 1)

# %%
sc = StandardScaler()
X = pd.DataFrame(sc.fit_transform(X))

# %%
cormat = X.corr()
fig, ax = plt.subplots(figsize = [13,13])
sns.heatmap(data = cormat, annot=True)
plt.show()

# %%
Y = to_categorical(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.05)
print("x_train_shape"+str(x_train.shape))
print("y_train_shape"+str(y_train.shape))
print("x_test_shape"+str(x_test.shape))
print("y_test_shape"+str(y_test.shape))
# Out:
# x_train_shape(169, 13)
# y_train_shape(169, 3)
# x_test_shape(9, 13)
# y_test_shape(9, 3)

# %%
nn = models.Sequential()
nn.add(layers.Dense(128, activation="relu",input_shape=(13, )))
nn.add(layers.Dense(64, activation="relu"))
nn.add(layers.Dense(32, activation="relu"))
nn.add(layers.Dense(16, activation="relu"))
nn.add(layers.Dense(3, activation="softmax"))

nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 128)               1792
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_26 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_27 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_28 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 12,707
# Trainable params: 12,707
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(optimizer="rmsprop",
           loss='categorical_crossentropy',
           metrics = ['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=300)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = nn.fit(x_train,y_train, epochs=5000, batch_size = 1000, validation_split=0.05, verbose=0, callbacks=[es, mc])
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.55556, saving model to best_model.h5
#
# Epoch 00002: val_accuracy did not improve from 0.55556
#
# Epoch 00003: val_accuracy did not improve from 0.55556
#
# Epoch 00004: val_accuracy did not improve from 0.55556
#
# Epoch 00005: val_accuracy did not improve from 0.55556
#
# Epoch 00006: val_accuracy did not improve from 0.55556
#
# Epoch 00007: val_accuracy improved from 0.55556 to 0.66667, saving model to best_model.h5
#
# Epoch 00008: val_accuracy improved from 0.66667 to 0.77778, saving model to best_model.h5
#
# Epoch 00009: val_accuracy did not improve from 0.77778
#
# Epoch 00010: val_accuracy did not improve from 0.77778
#
# Epoch 00011: val_accuracy did not improve from 0.77778
#
# Epoch 00012: val_accuracy did not improve from 0.77778
#
# Epoch 00013: val_accuracy did not improve from 0.77778
#
# Epoch 00014: val_accuracy did not improve from 0.77778
#
# Epoch 00015: val_accuracy did not improve from 0.77778
#
# Epoch 00016: val_accuracy improved from 0.77778 to 0.88889, saving model to best_model.h5
#
# Epoch 00017: val_accuracy did not improve from 0.88889
#
# Epoch 00018: val_accuracy did not improve from 0.88889
#
# Epoch 00019: val_accuracy did not improve from 0.88889
#
# Epoch 00020: val_accuracy did not improve from 0.88889
#
# Epoch 00021: val_accuracy did not improve from 0.88889
#
# Epoch 00022: val_accuracy did not improve from 0.88889
#
# Epoch 00023: val_accuracy did not improve from 0.88889
#
# Epoch 00024: val_accuracy did not improve from 0.88889
#
# Epoch 00025: val_accuracy did not improve from 0.88889
#
# Epoch 00026: val_accuracy did not improve from 0.88889
#
# Epoch 00027: val_accuracy did not improve from 0.88889
#
# Epoch 00028: val_accuracy did not improve from 0.88889
#
# Epoch 00029: val_accuracy did not improve from 0.88889
#
# Epoch 00030: val_accuracy did not improve from 0.88889
#
# Epoch 00031: val_accuracy did not improve from 0.88889
#
# Epoch 00032: val_accuracy did not improve from 0.88889
#
# Epoch 00033: val_accuracy did not improve from 0.88889
#
# Epoch 00034: val_accuracy did not improve from 0.88889
#
# Epoch 00035: val_accuracy did not improve from 0.88889
#
# Epoch 00036: val_accuracy did not improve from 0.88889
#
# Epoch 00037: val_accuracy did not improve from 0.88889
#
# Epoch 00038: val_accuracy did not improve from 0.88889
#
# Epoch 00039: val_accuracy did not improve from 0.88889
#
# Epoch 00040: val_accuracy did not improve from 0.88889
#
# Epoch 00041: val_accuracy did not improve from 0.88889
#
# Epoch 00042: val_accuracy did not improve from 0.88889
#
# Epoch 00043: val_accuracy did not improve from 0.88889
#
# Epoch 00044: val_accuracy did not improve from 0.88889
#
# Epoch 00045: val_accuracy did not improve from 0.88889
#
# Epoch 00046: val_accuracy did not improve from 0.88889
#
# Epoch 00047: val_accuracy did not improve from 0.88889
#
# Epoch 00048: val_accuracy did not improve from 0.88889
#
# Epoch 00049: val_accuracy did not improve from 0.88889
#
# Epoch 00050: val_accuracy did not improve from 0.88889
#
# Epoch 00051: val_accuracy did not improve from 0.88889
#
# Epoch 00052: val_accuracy did not improve from 0.88889
#
# Epoch 00053: val_accuracy did not improve from 0.88889
#
# Epoch 00054: val_accuracy did not improve from 0.88889
#
# Epoch 00055: val_accuracy did not improve from 0.88889
#
# Epoch 00056: val_accuracy did not improve from 0.88889
#
# Epoch 00057: val_accuracy did not improve from 0.88889
#
# Epoch 00058: val_accuracy did not improve from 0.88889
#
# Epoch 00059: val_accuracy did not improve from 0.88889
#
# Epoch 00060: val_accuracy did not improve from 0.88889
#
# Epoch 00061: val_accuracy did not improve from 0.88889
#
# Epoch 00062: val_accuracy did not improve from 0.88889
#
# Epoch 00063: val_accuracy did not improve from 0.88889
#
# Epoch 00064: val_accuracy did not improve from 0.88889
#
# Epoch 00065: val_accuracy did not improve from 0.88889
#
# Epoch 00066: val_accuracy did not improve from 0.88889
#
# Epoch 00067: val_accuracy did not improve from 0.88889
#
# Epoch 00068: val_accuracy did not improve from 0.88889
#
# Epoch 00069: val_accuracy did not improve from 0.88889
#
# Epoch 00070: val_accuracy did not improve from 0.88889
#
# Epoch 00071: val_accuracy did not improve from 0.88889
#
# Epoch 00072: val_accuracy did not improve from 0.88889
#
# Epoch 00073: val_accuracy did not improve from 0.88889
#
# Epoch 00074: val_accuracy did not improve from 0.88889
#
# Epoch 00075: val_accuracy did not improve from 0.88889
#
# Epoch 00076: val_accuracy did not improve from 0.88889
#
# Epoch 00077: val_accuracy did not improve from 0.88889
#
# Epoch 00078: val_accuracy did not improve from 0.88889
#
# Epoch 00079: val_accuracy did not improve from 0.88889
#
# Epoch 00080: val_accuracy did not improve from 0.88889
#
# Epoch 00081: val_accuracy did not improve from 0.88889
#
# Epoch 00082: val_accuracy did not improve from 0.88889
#
# Epoch 00083: val_accuracy did not improve from 0.88889
#
# Epoch 00084: val_accuracy did not improve from 0.88889
#
# Epoch 00085: val_accuracy did not improve from 0.88889
#
# Epoch 00086: val_accuracy did not improve from 0.88889
#
# Epoch 00087: val_accuracy did not improve from 0.88889
#
# Epoch 00088: val_accuracy did not improve from 0.88889
#
# Epoch 00089: val_accuracy did not improve from 0.88889
#
# Epoch 00090: val_accuracy did not improve from 0.88889
#
# Epoch 00091: val_accuracy did not improve from 0.88889
#
# Epoch 00092: val_accuracy did not improve from 0.88889
#
# Epoch 00093: val_accuracy did not improve from 0.88889
#
# Epoch 00094: val_accuracy did not improve from 0.88889
#
# Epoch 00095: val_accuracy did not improve from 0.88889
#
# Epoch 00096: val_accuracy did not improve from 0.88889
#
# Epoch 00097: val_accuracy did not improve from 0.88889
#
# Epoch 00098: val_accuracy did not improve from 0.88889
#
# Epoch 00099: val_accuracy did not improve from 0.88889
#
# Epoch 00100: val_accuracy did not improve from 0.88889
#
# Epoch 00101: val_accuracy did not improve from 0.88889
#
# Epoch 00102: val_accuracy did not improve from 0.88889
#
# Epoch 00103: val_accuracy did not improve from 0.88889
#
# Epoch 00104: val_accuracy did not improve from 0.88889
#
# Epoch 00105: val_accuracy did not improve from 0.88889
#
# Epoch 00106: val_accuracy did not improve from 0.88889
#
# Epoch 00107: val_accuracy did not improve from 0.88889
#
# Epoch 00108: val_accuracy did not improve from 0.88889
#
# Epoch 00109: val_accuracy did not improve from 0.88889
#
# Epoch 00110: val_accuracy did not improve from 0.88889
#
# Epoch 00111: val_accuracy did not improve from 0.88889
#
# Epoch 00112: val_accuracy did not improve from 0.88889
#
# Epoch 00113: val_accuracy did not improve from 0.88889
#
# Epoch 00114: val_accuracy did not improve from 0.88889
#
# Epoch 00115: val_accuracy did not improve from 0.88889
#
# Epoch 00116: val_accuracy did not improve from 0.88889
#
# Epoch 00117: val_accuracy did not improve from 0.88889
#
# Epoch 00118: val_accuracy did not improve from 0.88889
#
# Epoch 00119: val_accuracy did not improve from 0.88889
#
# Epoch 00120: val_accuracy did not improve from 0.88889
#
# Epoch 00121: val_accuracy did not improve from 0.88889
#
# Epoch 00122: val_accuracy did not improve from 0.88889
#
# Epoch 00123: val_accuracy did not improve from 0.88889
#
# Epoch 00124: val_accuracy did not improve from 0.88889
#
# Epoch 00125: val_accuracy did not improve from 0.88889
#
# Epoch 00126: val_accuracy did not improve from 0.88889
#
# Epoch 00127: val_accuracy did not improve from 0.88889
#
# Epoch 00128: val_accuracy did not improve from 0.88889
#
# Epoch 00129: val_accuracy did not improve from 0.88889
#
# Epoch 00130: val_accuracy did not improve from 0.88889
#
# Epoch 00131: val_accuracy did not improve from 0.88889
#
# Epoch 00132: val_accuracy did not improve from 0.88889
#
# Epoch 00133: val_accuracy did not improve from 0.88889
#
# Epoch 00134: val_accuracy did not improve from 0.88889
#
# Epoch 00135: val_accuracy did not improve from 0.88889
#
# Epoch 00136: val_accuracy did not improve from 0.88889
#
# Epoch 00137: val_accuracy improved from 0.88889 to 1.00000, saving model to best_model.h5
#
# Epoch 00138: val_accuracy did not improve from 1.00000
#
# Epoch 00139: val_accuracy did not improve from 1.00000
#
# Epoch 00140: val_accuracy did not improve from 1.00000
#
# Epoch 00141: val_accuracy did not improve from 1.00000
#
# Epoch 00142: val_accuracy did not improve from 1.00000
#
# Epoch 00143: val_accuracy did not improve from 1.00000
#
# Epoch 00144: val_accuracy did not improve from 1.00000
#
# Epoch 00145: val_accuracy did not improve from 1.00000
#
# Epoch 00146: val_accuracy did not improve from 1.00000
#
# Epoch 00147: val_accuracy did not improve from 1.00000
#
# Epoch 00148: val_accuracy did not improve from 1.00000
#
# Epoch 00149: val_accuracy did not improve from 1.00000
#
# Epoch 00150: val_accuracy did not improve from 1.00000
#
# Epoch 00151: val_accuracy did not improve from 1.00000
#
# Epoch 00152: val_accuracy did not improve from 1.00000
#
# Epoch 00153: val_accuracy did not improve from 1.00000
#
# Epoch 00154: val_accuracy did not improve from 1.00000
#
# Epoch 00155: val_accuracy did not improve from 1.00000
#
# Epoch 00156: val_accuracy did not improve from 1.00000
#
# Epoch 00157: val_accuracy did not improve from 1.00000
#
# Epoch 00158: val_accuracy did not improve from 1.00000
#
# Epoch 00159: val_accuracy did not improve from 1.00000
#
# Epoch 00160: val_accuracy did not improve from 1.00000
#
# Epoch 00161: val_accuracy did not improve from 1.00000
#
# Epoch 00162: val_accuracy did not improve from 1.00000
#
# Epoch 00163: val_accuracy did not improve from 1.00000
#
# Epoch 00164: val_accuracy did not improve from 1.00000
#
# Epoch 00165: val_accuracy did not improve from 1.00000
#
# Epoch 00166: val_accuracy did not improve from 1.00000
#
# Epoch 00167: val_accuracy did not improve from 1.00000
#
# Epoch 00168: val_accuracy did not improve from 1.00000
#
# Epoch 00169: val_accuracy did not improve from 1.00000
#
# Epoch 00170: val_accuracy did not improve from 1.00000
#
# Epoch 00171: val_accuracy did not improve from 1.00000
#
# Epoch 00172: val_accuracy did not improve from 1.00000
#
# Epoch 00173: val_accuracy did not improve from 1.00000
#
# Epoch 00174: val_accuracy did not improve from 1.00000
#
# Epoch 00175: val_accuracy did not improve from 1.00000
#
# Epoch 00176: val_accuracy did not improve from 1.00000
#
# Epoch 00177: val_accuracy did not improve from 1.00000
#
# Epoch 00178: val_accuracy did not improve from 1.00000
#
# Epoch 00179: val_accuracy did not improve from 1.00000
#
# Epoch 00180: val_accuracy did not improve from 1.00000
#
# Epoch 00181: val_accuracy did not improve from 1.00000
#
# Epoch 00182: val_accuracy did not improve from 1.00000
#
# Epoch 00183: val_accuracy did not improve from 1.00000
#
# Epoch 00184: val_accuracy did not improve from 1.00000
#
# Epoch 00185: val_accuracy did not improve from 1.00000
#
# Epoch 00186: val_accuracy did not improve from 1.00000
#
# Epoch 00187: val_accuracy did not improve from 1.00000
#
# Epoch 00188: val_accuracy did not improve from 1.00000
#
# Epoch 00189: val_accuracy did not improve from 1.00000
#
# Epoch 00190: val_accuracy did not improve from 1.00000
#
# Epoch 00191: val_accuracy did not improve from 1.00000
#
# Epoch 00192: val_accuracy did not improve from 1.00000
#
# Epoch 00193: val_accuracy did not improve from 1.00000
#
# Epoch 00194: val_accuracy did not improve from 1.00000
#
# Epoch 00195: val_accuracy did not improve from 1.00000
#
# Epoch 00196: val_accuracy did not improve from 1.00000
#
# Epoch 00197: val_accuracy did not improve from 1.00000
#
# Epoch 00198: val_accuracy did not improve from 1.00000
#
# Epoch 00199: val_accuracy did not improve from 1.00000
#
# Epoch 00200: val_accuracy did not improve from 1.00000
#
# Epoch 00201: val_accuracy did not improve from 1.00000
#
# Epoch 00202: val_accuracy did not improve from 1.00000
#
# Epoch 00203: val_accuracy did not improve from 1.00000
#
# Epoch 00204: val_accuracy did not improve from 1.00000
#
# Epoch 00205: val_accuracy did not improve from 1.00000
#
# Epoch 00206: val_accuracy did not improve from 1.00000
#
# Epoch 00207: val_accuracy did not improve from 1.00000
#
# Epoch 00208: val_accuracy did not improve from 1.00000
#
# Epoch 00209: val_accuracy did not improve from 1.00000
#
# Epoch 00210: val_accuracy did not improve from 1.00000
#
# Epoch 00211: val_accuracy did not improve from 1.00000
#
# Epoch 00212: val_accuracy did not improve from 1.00000
#
# Epoch 00213: val_accuracy did not improve from 1.00000
#
# Epoch 00214: val_accuracy did not improve from 1.00000
#
# Epoch 00215: val_accuracy did not improve from 1.00000
#
# Epoch 00216: val_accuracy did not improve from 1.00000
#
# Epoch 00217: val_accuracy did not improve from 1.00000
#
# Epoch 00218: val_accuracy did not improve from 1.00000
#
# Epoch 00219: val_accuracy did not improve from 1.00000
#
# Epoch 00220: val_accuracy did not improve from 1.00000
#
# Epoch 00221: val_accuracy did not improve from 1.00000
#
# Epoch 00222: val_accuracy did not improve from 1.00000
#
# Epoch 00223: val_accuracy did not improve from 1.00000
#
# Epoch 00224: val_accuracy did not improve from 1.00000
#
# Epoch 00225: val_accuracy did not improve from 1.00000
#
# Epoch 00226: val_accuracy did not improve from 1.00000
#
# Epoch 00227: val_accuracy did not improve from 1.00000
#
# Epoch 00228: val_accuracy did not improve from 1.00000
#
# Epoch 00229: val_accuracy did not improve from 1.00000
#
# Epoch 00230: val_accuracy did not improve from 1.00000
#
# Epoch 00231: val_accuracy did not improve from 1.00000
#
# Epoch 00232: val_accuracy did not improve from 1.00000
#
# Epoch 00233: val_accuracy did not improve from 1.00000
#
# Epoch 00234: val_accuracy did not improve from 1.00000
#
# Epoch 00235: val_accuracy did not improve from 1.00000
#
# Epoch 00236: val_accuracy did not improve from 1.00000
#
# Epoch 00237: val_accuracy did not improve from 1.00000
#
# Epoch 00238: val_accuracy did not improve from 1.00000
#
# Epoch 00239: val_accuracy did not improve from 1.00000
#
# Epoch 00240: val_accuracy did not improve from 1.00000
#
# Epoch 00241: val_accuracy did not improve from 1.00000
#
# Epoch 00242: val_accuracy did not improve from 1.00000
#
# Epoch 00243: val_accuracy did not improve from 1.00000
#
# Epoch 00244: val_accuracy did not improve from 1.00000
#
# Epoch 00245: val_accuracy did not improve from 1.00000
#
# Epoch 00246: val_accuracy did not improve from 1.00000
#
# Epoch 00247: val_accuracy did not improve from 1.00000
#
# Epoch 00248: val_accuracy did not improve from 1.00000
#
# Epoch 00249: val_accuracy did not improve from 1.00000
#
# Epoch 00250: val_accuracy did not improve from 1.00000
#
# Epoch 00251: val_accuracy did not improve from 1.00000
#
# Epoch 00252: val_accuracy did not improve from 1.00000
#
# Epoch 00253: val_accuracy did not improve from 1.00000
#
# Epoch 00254: val_accuracy did not improve from 1.00000
#
# Epoch 00255: val_accuracy did not improve from 1.00000
#
# Epoch 00256: val_accuracy did not improve from 1.00000
#
# Epoch 00257: val_accuracy did not improve from 1.00000
#
# Epoch 00258: val_accuracy did not improve from 1.00000
#
# Epoch 00259: val_accuracy did not improve from 1.00000
#
# Epoch 00260: val_accuracy did not improve from 1.00000
#
# Epoch 00261: val_accuracy did not improve from 1.00000
#
# Epoch 00262: val_accuracy did not improve from 1.00000
#
# Epoch 00263: val_accuracy did not improve from 1.00000
#
# Epoch 00264: val_accuracy did not improve from 1.00000
#
# Epoch 00265: val_accuracy did not improve from 1.00000
#
# Epoch 00266: val_accuracy did not improve from 1.00000
#
# Epoch 00267: val_accuracy did not improve from 1.00000
#
# Epoch 00268: val_accuracy did not improve from 1.00000
#
# Epoch 00269: val_accuracy did not improve from 1.00000
#
# Epoch 00270: val_accuracy did not improve from 1.00000
#
# Epoch 00271: val_accuracy did not improve from 1.00000
#
# Epoch 00272: val_accuracy did not improve from 1.00000
#
# Epoch 00273: val_accuracy did not improve from 1.00000
#
# Epoch 00274: val_accuracy did not improve from 1.00000
#
# Epoch 00275: val_accuracy did not improve from 1.00000
#
# Epoch 00276: val_accuracy did not improve from 1.00000
#
# Epoch 00277: val_accuracy did not improve from 1.00000
#
# Epoch 00278: val_accuracy did not improve from 1.00000
#
# Epoch 00279: val_accuracy did not improve from 1.00000
#
# Epoch 00280: val_accuracy did not improve from 1.00000
#
# Epoch 00281: val_accuracy did not improve from 1.00000
#
# Epoch 00282: val_accuracy did not improve from 1.00000
#
# Epoch 00283: val_accuracy did not improve from 1.00000
#
# Epoch 00284: val_accuracy did not improve from 1.00000
#
# Epoch 00285: val_accuracy did not improve from 1.00000
#
# Epoch 00286: val_accuracy did not improve from 1.00000
#
# Epoch 00287: val_accuracy did not improve from 1.00000
#
# Epoch 00288: val_accuracy did not improve from 1.00000
#
# Epoch 00289: val_accuracy did not improve from 1.00000
#
# Epoch 00290: val_accuracy did not improve from 1.00000
#
# Epoch 00291: val_accuracy did not improve from 1.00000
#
# Epoch 00292: val_accuracy did not improve from 1.00000
#
# Epoch 00293: val_accuracy did not improve from 1.00000
#
# Epoch 00294: val_accuracy did not improve from 1.00000
#
# Epoch 00295: val_accuracy did not improve from 1.00000
#
# Epoch 00296: val_accuracy did not improve from 1.00000
#
# Epoch 00297: val_accuracy did not improve from 1.00000
#
# Epoch 00298: val_accuracy did not improve from 1.00000
#
# Epoch 00299: val_accuracy did not improve from 1.00000
#
# Epoch 00300: val_accuracy did not improve from 1.00000
#
# Epoch 00301: val_accuracy did not improve from 1.00000
#
# Epoch 00302: val_accuracy did not improve from 1.00000
#
# Epoch 00303: val_accuracy did not improve from 1.00000
#
# Epoch 00304: val_accuracy did not improve from 1.00000
#
# Epoch 00305: val_accuracy did not improve from 1.00000
#
# Epoch 00306: val_accuracy did not improve from 1.00000
#
# Epoch 00307: val_accuracy did not improve from 1.00000
#
# Epoch 00308: val_accuracy did not improve from 1.00000
#
# Epoch 00309: val_accuracy did not improve from 1.00000
#
# Epoch 00310: val_accuracy did not improve from 1.00000
#
# Epoch 00311: val_accuracy did not improve from 1.00000
#
# Epoch 00312: val_accuracy did not improve from 1.00000
#
# Epoch 00313: val_accuracy did not improve from 1.00000
#
# Epoch 00314: val_accuracy did not improve from 1.00000
#
# Epoch 00315: val_accuracy did not improve from 1.00000
#
# Epoch 00316: val_accuracy did not improve from 1.00000
#
# Epoch 00317: val_accuracy did not improve from 1.00000
#
# Epoch 00318: val_accuracy did not improve from 1.00000
#
# Epoch 00319: val_accuracy did not improve from 1.00000
#
# Epoch 00320: val_accuracy did not improve from 1.00000
#
# Epoch 00321: val_accuracy did not improve from 1.00000
#
# Epoch 00322: val_accuracy did not improve from 1.00000
#
# Epoch 00323: val_accuracy did not improve from 1.00000
#
# Epoch 00324: val_accuracy did not improve from 1.00000
#
# Epoch 00325: val_accuracy did not improve from 1.00000
#
# Epoch 00326: val_accuracy did not improve from 1.00000
#
# Epoch 00327: val_accuracy did not improve from 1.00000
#
# Epoch 00328: val_accuracy did not improve from 1.00000
#
# Epoch 00329: val_accuracy did not improve from 1.00000
#
# Epoch 00330: val_accuracy did not improve from 1.00000
#
# Epoch 00331: val_accuracy did not improve from 1.00000
#
# Epoch 00332: val_accuracy did not improve from 1.00000
#
# Epoch 00333: val_accuracy did not improve from 1.00000
#
# Epoch 00334: val_accuracy did not improve from 1.00000
#
# Epoch 00335: val_accuracy did not improve from 1.00000
#
# Epoch 00336: val_accuracy did not improve from 1.00000
#
# Epoch 00337: val_accuracy did not improve from 1.00000
#
# Epoch 00338: val_accuracy did not improve from 1.00000
#
# Epoch 00339: val_accuracy did not improve from 1.00000
#
# Epoch 00340: val_accuracy did not improve from 1.00000
#
# Epoch 00341: val_accuracy did not improve from 1.00000
#
# Epoch 00342: val_accuracy did not improve from 1.00000
#
# Epoch 00343: val_accuracy did not improve from 1.00000
#
# Epoch 00344: val_accuracy did not improve from 1.00000
#
# Epoch 00345: val_accuracy did not improve from 1.00000
#
# Epoch 00346: val_accuracy did not improve from 1.00000
#
# Epoch 00347: val_accuracy did not improve from 1.00000
#
# Epoch 00348: val_accuracy did not improve from 1.00000
#
# Epoch 00349: val_accuracy did not improve from 1.00000
#
# Epoch 00350: val_accuracy did not improve from 1.00000
#
# Epoch 00351: val_accuracy did not improve from 1.00000
#
# Epoch 00352: val_accuracy did not improve from 1.00000
#
# Epoch 00353: val_accuracy did not improve from 1.00000
#
# Epoch 00354: val_accuracy did not improve from 1.00000
#
# Epoch 00355: val_accuracy did not improve from 1.00000
#
# Epoch 00356: val_accuracy did not improve from 1.00000
#
# Epoch 00357: val_accuracy did not improve from 1.00000
#
# Epoch 00358: val_accuracy did not improve from 1.00000
#
# Epoch 00359: val_accuracy did not improve from 1.00000
#
# Epoch 00360: val_accuracy did not improve from 1.00000
#
# Epoch 00361: val_accuracy did not improve from 1.00000
#
# Epoch 00362: val_accuracy did not improve from 1.00000
#
# Epoch 00363: val_accuracy did not improve from 1.00000
#
# Epoch 00364: val_accuracy did not improve from 1.00000
#
# Epoch 00365: val_accuracy did not improve from 1.00000
#
# Epoch 00366: val_accuracy did not improve from 1.00000
#
# Epoch 00367: val_accuracy did not improve from 1.00000
#
# Epoch 00368: val_accuracy did not improve from 1.00000
#
# Epoch 00369: val_accuracy did not improve from 1.00000
#
# Epoch 00370: val_accuracy did not improve from 1.00000
#
# Epoch 00371: val_accuracy did not improve from 1.00000
#
# Epoch 00372: val_accuracy did not improve from 1.00000
#
# Epoch 00373: val_accuracy did not improve from 1.00000
#
# Epoch 00374: val_accuracy did not improve from 1.00000
#
# Epoch 00375: val_accuracy did not improve from 1.00000
#
# Epoch 00376: val_accuracy did not improve from 1.00000
#
# Epoch 00377: val_accuracy did not improve from 1.00000
#
# Epoch 00378: val_accuracy did not improve from 1.00000
#
# Epoch 00379: val_accuracy did not improve from 1.00000
#
# Epoch 00380: val_accuracy did not improve from 1.00000
#
# Epoch 00381: val_accuracy did not improve from 1.00000
#
# Epoch 00382: val_accuracy did not improve from 1.00000
#
# Epoch 00383: val_accuracy did not improve from 1.00000
#
# Epoch 00384: val_accuracy did not improve from 1.00000
#
# Epoch 00385: val_accuracy did not improve from 1.00000
#
# Epoch 00386: val_accuracy did not improve from 1.00000
#
# Epoch 00387: val_accuracy did not improve from 1.00000
#
# Epoch 00388: val_accuracy did not improve from 1.00000
#
# Epoch 00389: val_accuracy did not improve from 1.00000
#
# Epoch 00390: val_accuracy did not improve from 1.00000
#
# Epoch 00391: val_accuracy did not improve from 1.00000
#
# Epoch 00392: val_accuracy did not improve from 1.00000
#
# Epoch 00393: val_accuracy did not improve from 1.00000
#
# Epoch 00394: val_accuracy did not improve from 1.00000
#
# Epoch 00395: val_accuracy did not improve from 1.00000
#
# Epoch 00396: val_accuracy did not improve from 1.00000
#
# Epoch 00397: val_accuracy did not improve from 1.00000
#
# Epoch 00398: val_accuracy did not improve from 1.00000
#
# Epoch 00399: val_accuracy did not improve from 1.00000
#
# Epoch 00400: val_accuracy did not improve from 1.00000
#
# Epoch 00401: val_accuracy did not improve from 1.00000
#
# Epoch 00402: val_accuracy did not improve from 1.00000
#
# Epoch 00403: val_accuracy did not improve from 1.00000
#
# Epoch 00404: val_accuracy did not improve from 1.00000
#
# Epoch 00405: val_accuracy did not improve from 1.00000
#
# Epoch 00406: val_accuracy did not improve from 1.00000
#
# Epoch 00407: val_accuracy did not improve from 1.00000
#
# Epoch 00408: val_accuracy did not improve from 1.00000
#
# Epoch 00409: val_accuracy did not improve from 1.00000
#
# Epoch 00410: val_accuracy did not improve from 1.00000
#
# Epoch 00411: val_accuracy did not improve from 1.00000
#
# Epoch 00412: val_accuracy did not improve from 1.00000
#
# Epoch 00413: val_accuracy did not improve from 1.00000
#
# Epoch 00414: val_accuracy did not improve from 1.00000
#
# Epoch 00415: val_accuracy did not improve from 1.00000
#
# Epoch 00416: val_accuracy did not improve from 1.00000
#
# Epoch 00417: val_accuracy did not improve from 1.00000
#
# Epoch 00418: val_accuracy did not improve from 1.00000
#
# Epoch 00419: val_accuracy did not improve from 1.00000
#
# Epoch 00420: val_accuracy did not improve from 1.00000
#
# Epoch 00421: val_accuracy did not improve from 1.00000
#
# Epoch 00422: val_accuracy did not improve from 1.00000
#
# Epoch 00423: val_accuracy did not improve from 1.00000
#
# Epoch 00424: val_accuracy did not improve from 1.00000
#
# Epoch 00425: val_accuracy did not improve from 1.00000
#
# Epoch 00426: val_accuracy did not improve from 1.00000
#
# Epoch 00427: val_accuracy did not improve from 1.00000
#
# Epoch 00428: val_accuracy did not improve from 1.00000
#
# Epoch 00429: val_accuracy did not improve from 1.00000
#
# Epoch 00430: val_accuracy did not improve from 1.00000
#
# Epoch 00431: val_accuracy did not improve from 1.00000
#
# Epoch 00432: val_accuracy did not improve from 1.00000
#
# Epoch 00433: val_accuracy did not improve from 1.00000
#
# Epoch 00434: val_accuracy did not improve from 1.00000
#
# Epoch 00435: val_accuracy did not improve from 1.00000
#
# Epoch 00436: val_accuracy did not improve from 1.00000
#
# Epoch 00437: val_accuracy did not improve from 1.00000
#
# Epoch 00438: val_accuracy did not improve from 1.00000
#
# Epoch 00439: val_accuracy did not improve from 1.00000
#
# Epoch 00440: val_accuracy did not improve from 1.00000
#
# Epoch 00441: val_accuracy did not improve from 1.00000
#
# Epoch 00442: val_accuracy did not improve from 1.00000
#
# Epoch 00443: val_accuracy did not improve from 1.00000
#
# Epoch 00444: val_accuracy did not improve from 1.00000
#
# Epoch 00445: val_accuracy did not improve from 1.00000
#
# Epoch 00446: val_accuracy did not improve from 1.00000
#
# Epoch 00447: val_accuracy did not improve from 1.00000
#
# Epoch 00448: val_accuracy did not improve from 1.00000
#
# Epoch 00449: val_accuracy did not improve from 1.00000
#
# Epoch 00450: val_accuracy did not improve from 1.00000
#
# Epoch 00451: val_accuracy did not improve from 1.00000
#
# Epoch 00452: val_accuracy did not improve from 1.00000
#
# Epoch 00453: val_accuracy did not improve from 1.00000
#
# Epoch 00454: val_accuracy did not improve from 1.00000
#
# Epoch 00455: val_accuracy did not improve from 1.00000
#
# Epoch 00456: val_accuracy did not improve from 1.00000
#
# Epoch 00457: val_accuracy did not improve from 1.00000
#
# Epoch 00458: val_accuracy did not improve from 1.00000
#
# Epoch 00459: val_accuracy did not improve from 1.00000
#
# Epoch 00460: val_accuracy did not improve from 1.00000
#
# Epoch 00461: val_accuracy did not improve from 1.00000
#
# Epoch 00462: val_accuracy did not improve from 1.00000
#
# Epoch 00463: val_accuracy did not improve from 1.00000
#
# Epoch 00464: val_accuracy did not improve from 1.00000
#
# Epoch 00465: val_accuracy did not improve from 1.00000
#
# Epoch 00466: val_accuracy did not improve from 1.00000
#
# Epoch 00467: val_accuracy did not improve from 1.00000
#
# Epoch 00468: val_accuracy did not improve from 1.00000
#
# Epoch 00469: val_accuracy did not improve from 1.00000
#
# Epoch 00470: val_accuracy did not improve from 1.00000
#
# Epoch 00471: val_accuracy did not improve from 1.00000
#
# Epoch 00472: val_accuracy did not improve from 1.00000
#
# Epoch 00473: val_accuracy did not improve from 1.00000
#
# Epoch 00474: val_accuracy did not improve from 1.00000
#
# Epoch 00475: val_accuracy did not improve from 1.00000
#
# Epoch 00476: val_accuracy did not improve from 1.00000
#
# Epoch 00477: val_accuracy did not improve from 1.00000
#
# Epoch 00478: val_accuracy did not improve from 1.00000
#
# Epoch 00479: val_accuracy did not improve from 1.00000
#
# Epoch 00480: val_accuracy did not improve from 1.00000
#
# Epoch 00481: val_accuracy did not improve from 1.00000
#
# Epoch 00482: val_accuracy did not improve from 1.00000
#
# Epoch 00483: val_accuracy did not improve from 1.00000
#
# Epoch 00484: val_accuracy did not improve from 1.00000
#
# Epoch 00485: val_accuracy did not improve from 1.00000
#
# Epoch 00486: val_accuracy did not improve from 1.00000
#
# Epoch 00487: val_accuracy did not improve from 1.00000
#
# Epoch 00488: val_accuracy did not improve from 1.00000
#
# Epoch 00489: val_accuracy did not improve from 1.00000
#
# Epoch 00490: val_accuracy did not improve from 1.00000
#
# Epoch 00491: val_accuracy did not improve from 1.00000
#
# Epoch 00492: val_accuracy did not improve from 1.00000
#
# Epoch 00493: val_accuracy did not improve from 1.00000
#
# Epoch 00494: val_accuracy did not improve from 1.00000
#
# Epoch 00495: val_accuracy did not improve from 1.00000
#
# Epoch 00496: val_accuracy did not improve from 1.00000
#
# Epoch 00497: val_accuracy did not improve from 1.00000
#
# Epoch 00498: val_accuracy did not improve from 1.00000
#
# Epoch 00499: val_accuracy did not improve from 1.00000
#
# Epoch 00500: val_accuracy did not improve from 1.00000
#
# Epoch 00501: val_accuracy did not improve from 1.00000
#
# Epoch 00502: val_accuracy did not improve from 1.00000
#
# Epoch 00503: val_accuracy did not improve from 1.00000
#
# Epoch 00504: val_accuracy did not improve from 1.00000
#
# Epoch 00505: val_accuracy did not improve from 1.00000
#
# Epoch 00506: val_accuracy did not improve from 1.00000
#
# Epoch 00507: val_accuracy did not improve from 1.00000
#
# Epoch 00508: val_accuracy did not improve from 1.00000
#
# Epoch 00509: val_accuracy did not improve from 1.00000
#
# Epoch 00510: val_accuracy did not improve from 1.00000
#
# Epoch 00511: val_accuracy did not improve from 1.00000
#
# Epoch 00512: val_accuracy did not improve from 1.00000
#
# Epoch 00513: val_accuracy did not improve from 1.00000
#
# Epoch 00514: val_accuracy did not improve from 1.00000
#
# Epoch 00515: val_accuracy did not improve from 1.00000
#
# Epoch 00516: val_accuracy did not improve from 1.00000
#
# Epoch 00517: val_accuracy did not improve from 1.00000
#
# Epoch 00518: val_accuracy did not improve from 1.00000
#
# Epoch 00519: val_accuracy did not improve from 1.00000
#
# Epoch 00520: val_accuracy did not improve from 1.00000
#
# Epoch 00521: val_accuracy did not improve from 1.00000
#
# Epoch 00522: val_accuracy did not improve from 1.00000
#
# Epoch 00523: val_accuracy did not improve from 1.00000
#
# Epoch 00524: val_accuracy did not improve from 1.00000
#
# Epoch 00525: val_accuracy did not improve from 1.00000
#
# Epoch 00526: val_accuracy did not improve from 1.00000
#
# Epoch 00527: val_accuracy did not improve from 1.00000
#
# Epoch 00528: val_accuracy did not improve from 1.00000
#
# Epoch 00529: val_accuracy did not improve from 1.00000
#
# Epoch 00530: val_accuracy did not improve from 1.00000
#
# Epoch 00531: val_accuracy did not improve from 1.00000
#
# Epoch 00532: val_accuracy did not improve from 1.00000
#
# Epoch 00533: val_accuracy did not improve from 1.00000
#
# Epoch 00534: val_accuracy did not improve from 1.00000
#
# Epoch 00535: val_accuracy did not improve from 1.00000
#
# Epoch 00536: val_accuracy did not improve from 1.00000
#
# Epoch 00537: val_accuracy did not improve from 1.00000
#
# Epoch 00538: val_accuracy did not improve from 1.00000
#
# Epoch 00539: val_accuracy did not improve from 1.00000
#
# Epoch 00540: val_accuracy did not improve from 1.00000
#
# Epoch 00541: val_accuracy did not improve from 1.00000
#
# Epoch 00542: val_accuracy did not improve from 1.00000
#
# Epoch 00543: val_accuracy did not improve from 1.00000
#
# Epoch 00544: val_accuracy did not improve from 1.00000
#
# Epoch 00545: val_accuracy did not improve from 1.00000
#
# Epoch 00546: val_accuracy did not improve from 1.00000
#
# Epoch 00547: val_accuracy did not improve from 1.00000
#
# Epoch 00548: val_accuracy did not improve from 1.00000
#
# Epoch 00549: val_accuracy did not improve from 1.00000
#
# Epoch 00550: val_accuracy did not improve from 1.00000
#
# Epoch 00551: val_accuracy did not improve from 1.00000
#
# Epoch 00552: val_accuracy did not improve from 1.00000
#
# Epoch 00553: val_accuracy did not improve from 1.00000
#
# Epoch 00554: val_accuracy did not improve from 1.00000
#
# Epoch 00555: val_accuracy did not improve from 1.00000
#
# Epoch 00556: val_accuracy did not improve from 1.00000
#
# Epoch 00557: val_accuracy did not improve from 1.00000
#
# Epoch 00558: val_accuracy did not improve from 1.00000
#
# Epoch 00559: val_accuracy did not improve from 1.00000
#
# Epoch 00560: val_accuracy did not improve from 1.00000
#
# Epoch 00561: val_accuracy did not improve from 1.00000
#
# Epoch 00562: val_accuracy did not improve from 1.00000
#
# Epoch 00563: val_accuracy did not improve from 1.00000
#
# Epoch 00564: val_accuracy did not improve from 1.00000
#
# Epoch 00565: val_accuracy did not improve from 1.00000
#
# Epoch 00566: val_accuracy did not improve from 1.00000
#
# Epoch 00567: val_accuracy did not improve from 1.00000
#
# Epoch 00568: val_accuracy did not improve from 1.00000
#
# Epoch 00569: val_accuracy did not improve from 1.00000
#
# Epoch 00570: val_accuracy did not improve from 1.00000
#
# Epoch 00571: val_accuracy did not improve from 1.00000
#
# Epoch 00572: val_accuracy did not improve from 1.00000
#
# Epoch 00573: val_accuracy did not improve from 1.00000
#
# Epoch 00574: val_accuracy did not improve from 1.00000
#
# Epoch 00575: val_accuracy did not improve from 1.00000
#
# Epoch 00576: val_accuracy did not improve from 1.00000
#
# Epoch 00577: val_accuracy did not improve from 1.00000
#
# Epoch 00578: val_accuracy did not improve from 1.00000
#
# Epoch 00579: val_accuracy did not improve from 1.00000
#
# Epoch 00580: val_accuracy did not improve from 1.00000
#
# Epoch 00581: val_accuracy did not improve from 1.00000
#
# Epoch 00582: val_accuracy did not improve from 1.00000
#
# Epoch 00583: val_accuracy did not improve from 1.00000
#
# Epoch 00584: val_accuracy did not improve from 1.00000
#
# Epoch 00585: val_accuracy did not improve from 1.00000
#
# Epoch 00586: val_accuracy did not improve from 1.00000
#
# Epoch 00587: val_accuracy did not improve from 1.00000
#
# Epoch 00588: val_accuracy did not improve from 1.00000
#
# Epoch 00589: val_accuracy did not improve from 1.00000
#
# Epoch 00590: val_accuracy did not improve from 1.00000
#
# Epoch 00591: val_accuracy did not improve from 1.00000
#
# Epoch 00592: val_accuracy did not improve from 1.00000
#
# Epoch 00593: val_accuracy did not improve from 1.00000
#
# Epoch 00594: val_accuracy did not improve from 1.00000
#
# Epoch 00595: val_accuracy did not improve from 1.00000
#
# Epoch 00596: val_accuracy did not improve from 1.00000
#
# Epoch 00597: val_accuracy did not improve from 1.00000
#
# Epoch 00598: val_accuracy did not improve from 1.00000
#
# Epoch 00599: val_accuracy did not improve from 1.00000
#
# Epoch 00600: val_accuracy did not improve from 1.00000
#
# Epoch 00601: val_accuracy did not improve from 1.00000
#
# Epoch 00602: val_accuracy did not improve from 1.00000
#
# Epoch 00603: val_accuracy did not improve from 1.00000
#
# Epoch 00604: val_accuracy did not improve from 1.00000
#
# Epoch 00605: val_accuracy did not improve from 1.00000
#
# Epoch 00606: val_accuracy did not improve from 1.00000
#
# Epoch 00607: val_accuracy did not improve from 1.00000
#
# Epoch 00608: val_accuracy did not improve from 1.00000
#
# Epoch 00609: val_accuracy did not improve from 1.00000
#
# Epoch 00610: val_accuracy did not improve from 1.00000
#
# Epoch 00611: val_accuracy did not improve from 1.00000
#
# Epoch 00612: val_accuracy did not improve from 1.00000
#
# Epoch 00613: val_accuracy did not improve from 1.00000
#
# Epoch 00614: val_accuracy did not improve from 1.00000
#
# Epoch 00615: val_accuracy did not improve from 1.00000
#
# Epoch 00616: val_accuracy did not improve from 1.00000
#
# Epoch 00617: val_accuracy did not improve from 1.00000
#
# Epoch 00618: val_accuracy did not improve from 1.00000
#
# Epoch 00619: val_accuracy did not improve from 1.00000
#
# Epoch 00620: val_accuracy did not improve from 1.00000
#
# Epoch 00621: val_accuracy did not improve from 1.00000
#
# Epoch 00622: val_accuracy did not improve from 1.00000
#
# Epoch 00623: val_accuracy did not improve from 1.00000
#
# Epoch 00624: val_accuracy did not improve from 1.00000
#
# Epoch 00625: val_accuracy did not improve from 1.00000
#
# Epoch 00626: val_accuracy did not improve from 1.00000
#
# Epoch 00627: val_accuracy did not improve from 1.00000
#
# Epoch 00628: val_accuracy did not improve from 1.00000
# Epoch 00628: early stopping

# %%
saved_model = load_model('best_model.h5')
_, test_acc = saved_model.evaluate(x_test, y_test, verbose=0)
print('Test: %.3f' % ( test_acc))
# Out:
# Test: 1.000

# %%
plt.figure(figsize = (10,7))
plt.plot(history.history['accuracy'], color = 'blue')
plt.plot(history.history['val_accuracy'], color = 'red')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.figure(figsize = (10,7))
plt.plot(history.history['loss'], color = 'blue')
plt.plot(history.history['val_loss'], color = 'red')
plt.ylim((0,1))
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
